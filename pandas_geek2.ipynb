# %% [markdown]
# #####  we learnt a little about the very useful library Pandas widely used for Data Analysis. It is time to put the many utilities of this library in front of our eyes. We will be performing following manipulations and exploration of our data

# %% [markdown]
# * Indexing and slicing operations
# * Manipulating columns
# * Exploring unique and missing values

# %%
# Import pandas package
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r'C:\Users\malik\Downloads\imdb_data1.csv')
df.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# 2  http://sonyclassics.com/whiplash/  tt2582802                en
# 3         http://kahaanithefilm.com/  tt1821480                hi
# 4                                NaN  tt1380152                ko
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                      마린보이
#
#                                             overview  popularity  ...  \
# 0  When Lou, who has become the "father of the In...    6.575393  ...
# 1  Mia Thermopolis is now a college graduate and ...    8.248895  ...
# 2  Under the direction of a ruthless instructor, ...   64.299990  ...
# 3  Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936  ...
# 4  Marine Boy is the story of a former national s...    1.148070  ...
#
#   release_date runtime                                   spoken_languages  \
# 0      2/20/15    93.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1       8/6/04   113.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2     10/10/14   105.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3       3/9/12   122.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 4       2/5/09   118.0           [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]
#
#      status                                            tagline  \
# 0  Released  The Laws of Space and Time are About to be Vio...
# 1  Released  It can take a lifetime to find true love; she'...
# 2  Released    The road to greatness can take you to the edge.
# 3  Released                                                NaN
# 4  Released                                                NaN
#
#                                       title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1  [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2  [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 3  [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 4                                                NaN
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1  [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2  [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3  [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4  [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
#
#                                                 crew   revenue
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651
# 1  [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435
# 2  [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000
# 3  [{'credit_id': '52fe48779251416c9108d6eb', 'de...  16000000
# 4  [{'credit_id': '52fe464b9251416c75073b43', 'de...   3923970
#
# [5 rows x 23 columns]

# %% [markdown]
# ### pd.read_csv()
# It is a function provided by the pandas library in Python, which is commonly used for data manipulation and analysis. This function is specifically designed to read data from CSV (Comma Separated Values) files and create a pandas DataFrame, which is a two-dimensional labeled data structure with columns of potentially different types.

# %% [markdown]
# #### r'...':
# This is a string containing the path to the CSV file. The r before the string denotes a raw string literal in Python, which is useful for specifying file paths because it treats backslashes (\) as literal characters rather than escape characters. You should replace the ... with the actual path to your CSV file.

# %%
df.shape
# Out:
# (3000, 23)

# %%
df.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# 2  http://sonyclassics.com/whiplash/  tt2582802                en
# 3         http://kahaanithefilm.com/  tt1821480                hi
# 4                                NaN  tt1380152                ko
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                      마린보이
#
#                                             overview  popularity  ...  \
# 0  When Lou, who has become the "father of the In...    6.575393  ...
# 1  Mia Thermopolis is now a college graduate and ...    8.248895  ...
# 2  Under the direction of a ruthless instructor, ...   64.299990  ...
# 3  Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936  ...
# 4  Marine Boy is the story of a former national s...    1.148070  ...
#
#   release_date runtime                                   spoken_languages  \
# 0      2/20/15    93.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1       8/6/04   113.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2     10/10/14   105.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3       3/9/12   122.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 4       2/5/09   118.0           [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]
#
#      status                                            tagline  \
# 0  Released  The Laws of Space and Time are About to be Vio...
# 1  Released  It can take a lifetime to find true love; she'...
# 2  Released    The road to greatness can take you to the edge.
# 3  Released                                                NaN
# 4  Released                                                NaN
#
#                                       title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1  [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2  [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 3  [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 4                                                NaN
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1  [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2  [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3  [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4  [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
#
#                                                 crew   revenue
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651
# 1  [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435
# 2  [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000
# 3  [{'credit_id': '52fe48779251416c9108d6eb', 'de...  16000000
# 4  [{'credit_id': '52fe464b9251416c75073b43', 'de...   3923970
#
# [5 rows x 23 columns]

# %%
df.tail(10)
# Out:
#         id                              belongs_to_collection    budget  \
# 2990  2991                                                NaN         0
# 2991  2992  [{'id': 107469, 'name': 'Save The Last Dance C...  13000000
# 2992  2993                                                NaN   1135654
# 2993  2994                                                NaN  60000000
# 2994  2995                                                NaN         0
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# 2990  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 2991  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 2992  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 2993  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2994                      [{'id': 18, 'name': 'Drama'}]
# 2995  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2996  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 2997  [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...
# 2998  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2999  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
#
#                                   homepage    imdb_id original_language  \
# 2990                                   NaN  tt0118663                en
# 2991                                   NaN  tt0206275                en
# 2992                                   NaN  tt0015400                en
# 2993  http://www.theterminal-themovie.com/  tt0362227                en
# 2994                                   NaN  tt0105327                en
# 2995                                   NaN  tt0109403                en
# 2996                                   NaN  tt2364975                sv
# 2997                                   NaN  tt0116908                en
# 2998        http://www.alongcamepolly.com/  tt0343135                en
# 2999      http://www.abductionthefilm.com/  tt1600195                en
#
#                original_title  \
# 2990                 B.A.P.S.
# 2991      Save the Last Dance
# 2992      The Thief of Bagdad
# 2993             The Terminal
# 2994              School Ties
# 2995                  Chasers
# 2996              Vi är bäst!
# 2997  The Long Kiss Goodnight
# 2998         Along Came Polly
# 2999                Abduction
#
#                                                overview  popularity  ...  \
# 2990  Can two clueless Georgia homegirls with big he...    1.560980  ...
# 2991  A white midwestern girl moves to Chicago, wher...    4.794088  ...
# 2992  A recalcitrant thief vies with a duplicitous M...    3.878515  ...
# 2993  Viktor Navorski is a man without a country; hi...   14.092373  ...
# 2994  When David Greene receives a football scholars...    7.438381  ...
# 2995  Military men Rock Reilly and Eddie Devane are ...    9.853270  ...
# 2996  Three girls in 1980s Stockholm decide to form ...    3.727996  ...
# 2997  Samantha Caine, suburban homemaker, is the ide...   14.482345  ...
# 2998  Reuben Feffer is a guy who's spent his entire ...   15.725542  ...
# 2999  A young man sets out to uncover the truth abou...   10.512109  ...
#
#      release_date runtime                                   spoken_languages  \
# 2990      3/28/97    90.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2991      1/12/01   112.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2992      3/18/24   149.0       [{'iso_639_1': 'xx', 'name': 'No Language'}]
# 2993      6/17/04   128.0  [{'iso_639_1': 'bg', 'name': 'български език'}...
# 2994      9/18/92   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2995      4/22/94   102.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2996      3/28/13   102.0           [{'iso_639_1': 'sv', 'name': 'svenska'}]
# 2997     10/11/96   120.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2998      1/16/04    90.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2999      9/22/11   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#         status                                            tagline  \
# 2990  Released                These Pretty Women... Are Clueless!
# 2991  Released        The Only Person You Need To Be Is Yourself.
# 2992  Released                         "Happiness Must Be Earned"
# 2993  Released                                   Life is waiting.
# 2994  Released  Just because you’re accepted doesn’t mean you ...
# 2995  Released  It was supposed to be a routine prisoner trans...
# 2996  Released                                                NaN
# 2997  Released               What's forgotten is not always gone.
# 2998  Released  For the most cautious man on Earth, life is ab...
# 2999  Released          They stole his life. He's taking it back.
#
#                         title  \
# 2990                 B.A.P.S.
# 2991      Save the Last Dance
# 2992      The Thief of Bagdad
# 2993             The Terminal
# 2994              School Ties
# 2995                  Chasers
# 2996         We Are the Best!
# 2997  The Long Kiss Goodnight
# 2998         Along Came Polly
# 2999                Abduction
#
#                                                Keywords  \
# 2990  [{'id': 1437, 'name': 'burglar'}, {'id': 1946,...
# 2991  [{'id': 4118, 'name': 'ballet dancer'}, {'id':...
# 2992  [{'id': 255, 'name': 'male nudity'}, {'id': 14...
# 2993  [{'id': 242, 'name': 'new york'}, {'id': 822, ...
# 2994  [{'id': 6075, 'name': 'sport'}, {'id': 10144, ...
# 2995  [{'id': 378, 'name': 'prison'}, {'id': 572, 'n...
# 2996  [{'id': 1192, 'name': 'sweden'}, {'id': 4470, ...
# 2997  [{'id': 441, 'name': 'assassination'}, {'id': ...
# 2998  [{'id': 966, 'name': 'beach'}, {'id': 2676, 'n...
# 2999  [{'id': 591, 'name': 'cia'}, {'id': 822, 'name...
#
#                                                    cast  \
# 2990  [{'cast_id': 3, 'character': 'Nisi', 'credit_i...
# 2991  [{'cast_id': 18, 'character': 'Sara Johnson', ...
# 2992  [{'cast_id': 3, 'character': 'The Thief of Bag...
# 2993  [{'cast_id': 4, 'character': 'Viktor Navorski'...
# 2994  [{'cast_id': 2, 'character': 'David Greene', '...
# 2995  [{'cast_id': 2, 'character': 'Rock Reilly', 'c...
# 2996  [{'cast_id': 5, 'character': 'Bobo', 'credit_i...
# 2997  [{'cast_id': 10, 'character': 'Samantha Caine ...
# 2998  [{'cast_id': 8, 'character': 'Reuben Feffer', ...
# 2999  [{'cast_id': 2, 'character': 'Nathan Harper', ...
#
#                                                    crew    revenue
# 2990  [{'credit_id': '52fe477b9251416c7509af57', 'de...    7240837
# 2991  [{'credit_id': '52fe4533c3a36847f80c1c6b', 'de...   91038276
# 2992  [{'credit_id': '52fe45bec3a368484e06c70b', 'de...    1213880
# 2993  [{'credit_id': '52fe4259c3a36847f8017699', 'de...  219417255
# 2994  [{'credit_id': '5637777ac3a3681b4d01f9f5', 'de...   14715067
# 2995  [{'credit_id': '52fe4494c3a368484e02ac7d', 'de...    1596687
# 2996  [{'credit_id': '5716b72ac3a3686678012c84', 'de...     180590
# 2997  [{'credit_id': '52fe443a9251416c7502d579', 'de...   89456761
# 2998  [{'credit_id': '556f817b9251410866000a63', 'de...  171963386
# 2999  [{'credit_id': '5391990d0e0a260fb5001629', 'de...   82087155
#
# [10 rows x 23 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     3000 non-null   int64
#  1   belongs_to_collection  604 non-null    object
#  2   budget                 3000 non-null   int64
#  3   genres                 2993 non-null   object
#  4   homepage               946 non-null    object
#  5   imdb_id                3000 non-null   object
#  6   original_language      3000 non-null   object
#  7   original_title         3000 non-null   object
#  8   overview               2992 non-null   object
#  9   popularity             3000 non-null   float64
#  10  poster_path            2999 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2945 non-null   object
#  13  release_date           3000 non-null   object
#  14  runtime                2998 non-null   float64
#  15  spoken_languages       2980 non-null   object
#  16  status                 3000 non-null   object
#  17  tagline                2403 non-null   object
#  18  title                  3000 non-null   object
#  19  Keywords               2724 non-null   object
#  20  cast                   2987 non-null   object
#  21  crew                   2984 non-null   object
#  22  revenue                3000 non-null   int64
# dtypes: float64(2), int64(3), object(18)
# memory usage: 539.2+ KB

# %% [markdown]
# ### info()
# * it is a method provided by the pandas library in Python, which is used to display a concise summary of a DataFrame

# %% [markdown]
# ### describe()
# * This method gives the overall descriptive summary of the dataframe. This works only for numerical columns

# %%
df.describe()
# Out:
#                 id        budget   popularity      runtime       revenue
# count  3000.000000  3.000000e+03  3000.000000  2998.000000  3.000000e+03
# mean   1500.500000  2.253133e+07     8.463274   107.856571  6.672585e+07
# std     866.169729  3.702609e+07    12.104000    22.086434  1.375323e+08
# min       1.000000  0.000000e+00     0.000001     0.000000  1.000000e+00
# 25%     750.750000  0.000000e+00     4.018053    94.000000  2.379808e+06
# 50%    1500.500000  8.000000e+06     7.374861   104.000000  1.680707e+07
# 75%    2250.250000  2.900000e+07    10.890983   118.000000  6.891920e+07
# max    3000.000000  3.800000e+08   294.337037   338.000000  1.519558e+09

# %% [markdown]
# # <u>**Indexing and Slicing**</u>

# %% [markdown]
# #### **<code>iloc</code>** gets rows (or columns) at particular positions in the index (so it only takes integers).

# %%
# Let us get a subset which consists of first 8 rows and first 4 columns
df.iloc[:,-3:]
# Out:
#                                                    cast  \
# 0     [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1     [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2     [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3     [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4     [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
# ...                                                 ...
# 2995  [{'cast_id': 2, 'character': 'Rock Reilly', 'c...
# 2996  [{'cast_id': 5, 'character': 'Bobo', 'credit_i...
# 2997  [{'cast_id': 10, 'character': 'Samantha Caine ...
# 2998  [{'cast_id': 8, 'character': 'Reuben Feffer', ...
# 2999  [{'cast_id': 2, 'character': 'Nathan Harper', ...
#
#                                                    crew    revenue
# 0     [{'credit_id': '59ac067c92514107af02c8c8', 'de...   12314651
# 1     [{'credit_id': '52fe43fe9251416c7502563d', 'de...   95149435
# 2     [{'credit_id': '54d5356ec3a3683ba0000039', 'de...   13092000
# 3     [{'credit_id': '52fe48779251416c9108d6eb', 'de...   16000000
# 4     [{'credit_id': '52fe464b9251416c75073b43', 'de...    3923970
# ...                                                 ...        ...
# 2995  [{'credit_id': '52fe4494c3a368484e02ac7d', 'de...    1596687
# 2996  [{'credit_id': '5716b72ac3a3686678012c84', 'de...     180590
# 2997  [{'credit_id': '52fe443a9251416c7502d579', 'de...   89456761
# 2998  [{'credit_id': '556f817b9251410866000a63', 'de...  171963386
# 2999  [{'credit_id': '5391990d0e0a260fb5001629', 'de...   82087155
#
# [3000 rows x 3 columns]

# %% [markdown]
# #### **<code>loc</code>** gets rows (or columns) with particular labels from the index.

# %%
# Now let us subset our dataframe in which we want to have first 8 rows identified with their rows labels and some named columns
df.loc[50:60,['budget','genres','runtime']]
# Out:
#        budget                                             genres  runtime
# 50     560000  [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...    102.0
# 51   12000000  [{'id': 12, 'name': 'Adventure'}, {'id': 35, '...    160.0
# 52          0  [{'id': 12, 'name': 'Adventure'}, {'id': 10751...     97.0
# 53          0  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...     98.0
# 54   20000000                     [{'id': 28, 'name': 'Action'}]    107.0
# 55          0  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...     95.0
# 56          0  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...     97.0
# 57  125000000  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...    125.0
# 58          0  [{'id': 10402, 'name': 'Music'}, {'id': 10749,...     95.0
# 59   14000000  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...     95.0
# 60  150000000  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...    144.0

# %%
df.loc[:,['budget','genres','runtime']]
# Out:
#         budget                                             genres  runtime
# 0     14000000                     [{'id': 35, 'name': 'Comedy'}]     93.0
# 1     40000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...    113.0
# 2      3300000                      [{'id': 18, 'name': 'Drama'}]    105.0
# 3      1200000  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...    122.0
# 4            0  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...    118.0
# ...        ...                                                ...      ...
# 2995         0  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...    102.0
# 2996         0  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...    102.0
# 2997  65000000  [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...    120.0
# 2998  42000000  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...     90.0
# 2999  35000000  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...    106.0
#
# [3000 rows x 3 columns]

# %%
df[0:10]
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
# 5   6                                                NaN   8000000
# 6   7                                                NaN  14000000
# 7   8                                                NaN         0
# 8   9  [{'id': 256377, 'name': 'The Muppet Collection...         0
# 9  10                                                NaN   6000000
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 5  [{'id': 16, 'name': 'Animation'}, {'id': 12, '...
# 6  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
# 7                [{'id': 99, 'name': 'Documentary'}]
# 8  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 9  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...
#
#                              homepage    imdb_id original_language  \
# 0                                 NaN  tt2637294                en
# 1                                 NaN  tt0368933                en
# 2   http://sonyclassics.com/whiplash/  tt2582802                en
# 3          http://kahaanithefilm.com/  tt1821480                hi
# 4                                 NaN  tt1380152                ko
# 5                                 NaN  tt0093743                en
# 6  http://www.thepossessionmovie.com/  tt0431021                en
# 7                                 NaN  tt0391024                en
# 8                                 NaN  tt0117110                en
# 9                                 NaN  tt0310281                en
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                      마린보이
# 5    Pinocchio and the Emperor of the Night
# 6                            The Possession
# 7                              Control Room
# 8                    Muppet Treasure Island
# 9                             A Mighty Wind
#
#                                             overview  popularity  ...  \
# 0  When Lou, who has become the "father of the In...    6.575393  ...
# 1  Mia Thermopolis is now a college graduate and ...    8.248895  ...
# 2  Under the direction of a ruthless instructor, ...   64.299990  ...
# 3  Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936  ...
# 4  Marine Boy is the story of a former national s...    1.148070  ...
# 5  Pinocchio and his friends, a glow worm and a m...    0.743274  ...
# 6  A young girl buys an antique box at a yard sal...    7.286477  ...
# 7  A chronicle which provides a rare window into ...    1.949044  ...
# 8  After telling the story of Flint's last journe...    6.902423  ...
# 9  In "A Mighty Wind", director Christopher Guest...    4.672036  ...
#
#   release_date runtime                                   spoken_languages  \
# 0      2/20/15    93.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1       8/6/04   113.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2     10/10/14   105.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3       3/9/12   122.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 4       2/5/09   118.0           [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]
# 5       8/6/87    83.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 6      8/30/12    92.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 7      1/15/04    84.0  [{'iso_639_1': 'ar', 'name': 'العربية'}, {'iso...
# 8      2/16/96   100.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 9      4/16/03    91.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released  The Laws of Space and Time are About to be Vio...
# 1  Released  It can take a lifetime to find true love; she'...
# 2  Released    The road to greatness can take you to the edge.
# 3  Released                                                NaN
# 4  Released                                                NaN
# 5  Released                                                NaN
# 6  Released               Fear The Demon That Doesn't Fear God
# 7  Released              Different channels. Different truths.
# 8  Released                        Set sail for Muppet mayhem!
# 9  Released           Back together for the first time, again.
#
#                                       title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy
# 5    Pinocchio and the Emperor of the Night
# 6                            The Possession
# 7                              Control Room
# 8                    Muppet Treasure Island
# 9                             A Mighty Wind
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1  [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2  [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 3  [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7  [{'id': 917, 'name': 'journalism'}, {'id': 163...
# 8  [{'id': 2041, 'name': 'island'}, {'id': 4418, ...
# 9  [{'id': 11800, 'name': 'mockumentary'}, {'id':...
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1  [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2  [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3  [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4  [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
# 5  [{'cast_id': 6, 'character': 'Pinocchio (voice...
# 6  [{'cast_id': 23, 'character': 'Clyde', 'credit...
# 7  [{'cast_id': 2, 'character': 'Himself', 'credi...
# 8  [{'cast_id': 1, 'character': 'Long John Silver...
# 9  [{'cast_id': 24, 'character': 'Jonathan Steinb...
#
#                                                 crew   revenue
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651
# 1  [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435
# 2  [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000
# 3  [{'credit_id': '52fe48779251416c9108d6eb', 'de...  16000000
# 4  [{'credit_id': '52fe464b9251416c75073b43', 'de...   3923970
# 5  [{'credit_id': '52fe46f49251416c9106558b', 'de...   3261638
# 6  [{'credit_id': '52fe4981c3a368484e12ee29', 'de...  85446075
# 7  [{'credit_id': '52fe47a69251416c750a0daf', 'de...   2586511
# 8  [{'credit_id': '52fe43c89251416c7501deb3', 'de...  34327391
# 9  [{'credit_id': '52fe45609251416c750545b3', 'de...  18750246
#
# [10 rows x 23 columns]

# %%
df[['original_language','release_date','cast']]
# Out:
#      original_language release_date  \
# 0                   en      2/20/15
# 1                   en       8/6/04
# 2                   en     10/10/14
# 3                   hi       3/9/12
# 4                   ko       2/5/09
# ...                ...          ...
# 2995                en      4/22/94
# 2996                sv      3/28/13
# 2997                en     10/11/96
# 2998                en      1/16/04
# 2999                en      9/22/11
#
#                                                    cast
# 0     [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1     [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2     [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3     [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4     [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
# ...                                                 ...
# 2995  [{'cast_id': 2, 'character': 'Rock Reilly', 'c...
# 2996  [{'cast_id': 5, 'character': 'Bobo', 'credit_i...
# 2997  [{'cast_id': 10, 'character': 'Samantha Caine ...
# 2998  [{'cast_id': 8, 'character': 'Reuben Feffer', ...
# 2999  [{'cast_id': 2, 'character': 'Nathan Harper', ...
#
# [3000 rows x 3 columns]

# %%
df.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue'],
#       dtype='object')

# %% [markdown]
# ### <b>In fact we can also perform boolean indexing on our dataframe</b>

# %%
df['original_language'] == 'en'
# Out:
# 0        True
# 1        True
# 2        True
# 3       False
# 4       False
#         ...
# 2995     True
# 2996    False
# 2997     True
# 2998     True
# 2999     True
# Name: original_language, Length: 3000, dtype: bool

# %%
# Boolean Indexing
english_movies = df[df['original_language'] == 'en']
english_movies.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 5   6                                                NaN   8000000
# 6   7                                                NaN  14000000
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 5  [{'id': 16, 'name': 'Animation'}, {'id': 12, '...
# 6  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
#
#                              homepage    imdb_id original_language  \
# 0                                 NaN  tt2637294                en
# 1                                 NaN  tt0368933                en
# 2   http://sonyclassics.com/whiplash/  tt2582802                en
# 5                                 NaN  tt0093743                en
# 6  http://www.thepossessionmovie.com/  tt0431021                en
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 5    Pinocchio and the Emperor of the Night
# 6                            The Possession
#
#                                             overview  popularity  ...  \
# 0  When Lou, who has become the "father of the In...    6.575393  ...
# 1  Mia Thermopolis is now a college graduate and ...    8.248895  ...
# 2  Under the direction of a ruthless instructor, ...   64.299990  ...
# 5  Pinocchio and his friends, a glow worm and a m...    0.743274  ...
# 6  A young girl buys an antique box at a yard sal...    7.286477  ...
#
#   release_date runtime                          spoken_languages    status  \
# 0      2/20/15    93.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1       8/6/04   113.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2     10/10/14   105.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 5       8/6/87    83.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 6      8/30/12    92.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline  \
# 0  The Laws of Space and Time are About to be Vio...
# 1  It can take a lifetime to find true love; she'...
# 2    The road to greatness can take you to the edge.
# 5                                                NaN
# 6               Fear The Demon That Doesn't Fear God
#
#                                       title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 5    Pinocchio and the Emperor of the Night
# 6                            The Possession
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1  [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2  [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 5                                                NaN
# 6                                                NaN
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1  [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2  [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 5  [{'cast_id': 6, 'character': 'Pinocchio (voice...
# 6  [{'cast_id': 23, 'character': 'Clyde', 'credit...
#
#                                                 crew   revenue
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651
# 1  [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435
# 2  [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000
# 5  [{'credit_id': '52fe46f49251416c9106558b', 'de...   3261638
# 6  [{'credit_id': '52fe4981c3a368484e12ee29', 'de...  85446075
#
# [5 rows x 23 columns]

# %%
non_english_movies = df[df['original_language'] != 'en']
non_english_movies.head()
# Out:
#     id belongs_to_collection    budget  \
# 3    4                   NaN   1200000
# 4    5                   NaN         0
# 15  16                   NaN    500000
# 30  31                   NaN  13000000
# 31  32                   NaN         0
#
#                                                genres  \
# 3   [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4   [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 15  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 30  [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...
# 31  [{'id': 9648, 'name': 'Mystery'}, {'id': 18, '...
#
#                                  homepage    imdb_id original_language  \
# 3              http://kahaanithefilm.com/  tt1821480                hi
# 4                                     NaN  tt1380152                ko
# 15  http://skinningmovie.com/synopsis.htm  tt1129437                sr
# 30                                    NaN  tt1675434                fr
# 31            http://www.cache-derfilm.at  tt0387898                fr
#
#    original_title                                           overview  \
# 3         Kahaani  Vidya Bagchi (Vidya Balan) arrives in Kolkata ...
# 4            마린보이  Marine Boy is the story of a former national s...
# 15        Šišanje  Novica is a mathematics champion in a Belgrade...
# 30   Intouchables  A true story of two men who should never have ...
# 31          Caché  A married couple is terrorized by a series of ...
#
#     popularity  ... release_date runtime  \
# 3     3.174936  ...       3/9/12   122.0
# 4     1.148070  ...       2/5/09   118.0
# 15    1.018477  ...      10/6/10    97.0
# 30   16.086919  ...      11/2/11   112.0
# 31    5.695860  ...       5/2/05   117.0
#
#                                      spoken_languages    status  \
# 3   [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 4            [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]  Released
# 15            [{'iso_639_1': 'sr', 'name': 'Srpski'}]  Released
# 30  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 31          [{'iso_639_1': 'fr', 'name': 'Français'}]  Released
#
#                                               tagline             title  \
# 3                                                 NaN           Kahaani
# 4                                                 NaN        Marine Boy
# 15  Life is sometimes rude game: one mistake can b...          Skinning
# 30  Sometimes you have to reach into someone else'...  The Intouchables
# 31                                                NaN             Caché
#
#                                              Keywords  \
# 3   [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 4                                                 NaN
# 15  [{'id': 379, 'name': 'skinhead'}, {'id': 7492,...
# 30  [{'id': 3230, 'name': 'male friendship'}, {'id...
# 31  [{'id': 90, 'name': 'paris'}, {'id': 213, 'nam...
#
#                                                  cast  \
# 3   [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4   [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
# 15  [{'cast_id': 1001, 'character': 'Novica', 'cre...
# 30  [{'cast_id': 6, 'character': 'Philippe', 'cred...
# 31  [{'cast_id': 2, 'character': 'Georges Laurent'...
#
#                                                  crew    revenue
# 3   [{'credit_id': '52fe48779251416c9108d6eb', 'de...   16000000
# 4   [{'credit_id': '52fe464b9251416c75073b43', 'de...    3923970
# 15  [{'credit_id': '52fe4927c3a36847f818bb5f', 'de...        198
# 30  [{'credit_id': '52fe4967c3a368484e129b63', 'de...  426480871
# 31  [{'credit_id': '52fe4244c3a36847f8011073', 'de...   36000000
#
# [5 rows x 23 columns]

# %%
long_movies = df[df['runtime'] > 120]
long_movies[['title','cast']]
# Out:
#                     title                                               cast
# 3                 Kahaani  [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 12        American Beauty  [{'cast_id': 6, 'character': 'Lester Burnham',...
# 14        Minority Report  [{'cast_id': 5, 'character': 'Chief John Ander...
# 20          Lost in Space  [{'cast_id': 26, 'character': 'Dr. Zachary Smi...
# 33        ABCs of Death 2  [{'cast_id': 60, 'character': 'Assassin (Segme...
# ...                   ...                                                ...
# 2969         Gosford Park  [{'cast_id': 2, 'character': 'Mrs. Wilson', 'c...
# 2970        The Bodyguard  [{'cast_id': 17, 'character': 'Rachel Marron',...
# 2980     Action Hero Biju  [{'cast_id': 1, 'character': 'Sub-Inspector Bi...
# 2992  The Thief of Bagdad  [{'cast_id': 3, 'character': 'The Thief of Bag...
# 2993         The Terminal  [{'cast_id': 4, 'character': 'Viktor Navorski'...
#
# [657 rows x 2 columns]

# %% [markdown]
# ### <b>Infact we can match conditions for mutliple columns

# %%
long_movies = df[df['runtime'] > 120]

# %%
long_movies.tail()
# Out:
#         id belongs_to_collection    budget  \
# 2969  2970                   NaN  19800000
# 2970  2971                   NaN  25000000
# 2980  2981                   NaN    300000
# 2992  2993                   NaN   1135654
# 2993  2994                   NaN  60000000
#
#                                                  genres  \
# 2969  [{'id': 18, 'name': 'Drama'}, {'id': 9648, 'na...
# 2970  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
# 2980  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 2992  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 2993  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
#
#                                       homepage    imdb_id original_language  \
# 2969                                       NaN  tt0280707                en
# 2970                                       NaN  tt0103855                en
# 2980  https://www.facebook.com/Actionherobiju/  tt5320514                ml
# 2992                                       NaN  tt0015400                en
# 2993      http://www.theterminal-themovie.com/  tt0362227                en
#
#            original_title                                           overview  \
# 2969         Gosford Park  Multiple storylined drama set in 1932, showing...
# 2970        The Bodyguard  A former Secret Service agent grudgingly takes...
# 2980      ആക്ഷൻ ഹീറോ ബിജു  Biju is an honest policeman who fights the inj...
# 2992  The Thief of Bagdad  A recalcitrant thief vies with a duplicitous M...
# 2993         The Terminal  Viktor Navorski is a man without a country; hi...
#
#       popularity  ... release_date runtime  \
# 2969   14.101101  ...      11/7/01   137.0
# 2970    9.805017  ...     11/25/92   129.0
# 2980    0.350207  ...       2/4/16   144.0
# 2992    3.878515  ...      3/18/24   149.0
# 2993   14.092373  ...      6/17/04   128.0
#
#                                        spoken_languages    status  \
# 2969           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2970           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2980                  [{'iso_639_1': 'ml', 'name': ''}]  Released
# 2992       [{'iso_639_1': 'xx', 'name': 'No Language'}]  Released
# 2993  [{'iso_639_1': 'bg', 'name': 'български език'}...  Released
#
#                                                 tagline                title  \
# 2969  Tea at four. Dinner at eight. Murder at midnight.         Gosford Park
# 2970  Never let her out of your sight. Never let you...        The Bodyguard
# 2980                       A ride with a police officer     Action Hero Biju
# 2992                         "Happiness Must Be Earned"  The Thief of Bagdad
# 2993                                   Life is waiting.         The Terminal
#
#                                                Keywords  \
# 2969  [{'id': 964, 'name': 'servant'}, {'id': 10594,...
# 2970  [{'id': 1156, 'name': 'sister sister relations...
# 2980  [{'id': 1252, 'name': 'suicide attempt'}, {'id...
# 2992  [{'id': 255, 'name': 'male nudity'}, {'id': 14...
# 2993  [{'id': 242, 'name': 'new york'}, {'id': 822, ...
#
#                                                    cast  \
# 2969  [{'cast_id': 2, 'character': 'Mrs. Wilson', 'c...
# 2970  [{'cast_id': 17, 'character': 'Rachel Marron',...
# 2980  [{'cast_id': 1, 'character': 'Sub-Inspector Bi...
# 2992  [{'cast_id': 3, 'character': 'The Thief of Bag...
# 2993  [{'cast_id': 4, 'character': 'Viktor Navorski'...
#
#                                                    crew    revenue
# 2969  [{'credit_id': '52fe4401c3a36847f807ceab', 'de...   87754044
# 2970  [{'credit_id': '52fe425ec3a36847f8019133', 'de...  411006740
# 2980  [{'credit_id': '56b4d47f92514112b90045f6', 'de...    2500000
# 2992  [{'credit_id': '52fe45bec3a368484e06c70b', 'de...    1213880
# 2993  [{'credit_id': '52fe4259c3a36847f8017699', 'de...  219417255
#
# [5 rows x 23 columns]

# %%
(df['original_language']=='en') & (df['runtime'] > 120)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2995    False
# 2996    False
# 2997    False
# 2998    False
# 2999    False
# Length: 3000, dtype: bool

# %%
long_english_movies = df[(df['original_language']=='en') & (df['runtime'] > 120)]
long_english_movies.head()
# Out:
#     id                              belongs_to_collection     budget  \
# 12  13                                                NaN   15000000
# 14  15                                                NaN  102000000
# 20  21                                                NaN   80000000
# 33  34  [{'id': 207632, 'name': 'The ABCs of Death Col...          0
# 37  38                                                NaN   50000000
#
#                                                genres  \
# 12                      [{'id': 18, 'name': 'Drama'}]
# 14  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 20  [{'id': 12, 'name': 'Adventure'}, {'id': 10751...
# 33                     [{'id': 27, 'name': 'Horror'}]
# 37  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
#
#                          homepage    imdb_id original_language  \
# 12  http://www.dreamworks.com/ab/  tt0169547                en
# 14                            NaN  tt0181689                en
# 20                            NaN  tt0120738                en
# 33                            NaN  tt2926810                en
# 37                            NaN  tt0114069                en
#
#      original_title                                           overview  \
# 12  American Beauty  Lester Burnham, a depressed suburban father in...
# 14  Minority Report  John Anderton is a top 'Precrime' cop in the l...
# 20    Lost in Space  The prospects for continuing life on Earth in ...
# 33  ABCs of Death 2  Taking all that was great from the first insta...
# 37         Outbreak  A deadly airborne virus finds its way into the...
#
#     popularity  ... release_date runtime  \
# 12   20.726578  ...      9/15/99   122.0
# 14   20.666063  ...      6/20/02   145.0
# 20   12.000579  ...       4/3/98   130.0
# 33    8.254856  ...      10/2/14   125.0
# 37   13.676444  ...      3/10/95   127.0
#
#                                      spoken_languages    status  \
# 12           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 14  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 20           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 33  [{'iso_639_1': 'ar', 'name': 'العربية'}, {'iso...  Released
# 37  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
#
#                                               tagline            title  \
# 12                                       Look closer.  American Beauty
# 14    The system is perfect until it comes after you.  Minority Report
# 20                             Danger, Will Robinson!    Lost in Space
# 33                            Some people never learn  ABCs of Death 2
# 37  This animal carries a deadly virus... and the ...         Outbreak
#
#                                              Keywords  \
# 12  [{'id': 255, 'name': 'male nudity'}, {'id': 29...
# 14  [{'id': 476, 'name': 'self-fulfilling prophecy...
# 20  [{'id': 4379, 'name': 'time travel'}, {'id': 1...
# 33  [{'id': 9706, 'name': 'anthology'}, {'id': 187...
# 37  [{'id': 1261, 'name': 'river'}, {'id': 1402, '...
#
#                                                  cast  \
# 12  [{'cast_id': 6, 'character': 'Lester Burnham',...
# 14  [{'cast_id': 5, 'character': 'Chief John Ander...
# 20  [{'cast_id': 26, 'character': 'Dr. Zachary Smi...
# 33  [{'cast_id': 60, 'character': 'Assassin (Segme...
# 37  [{'cast_id': 1, 'character': 'Sam Daniels', 'c...
#
#                                                  crew    revenue
# 12  [{'credit_id': '52fe420ec3a36847f80007c5', 'de...  356296601
# 14  [{'credit_id': '52fe4223c3a36847f8006f3d', 'de...  358372926
# 20  [{'credit_id': '52fe433bc3a36847f80448b9', 'de...  136159423
# 33  [{'credit_id': '52fe4cd69251416c91101d73', 'de...       7171
# 37  [{'credit_id': '52fe446ac3a36847f80949d3', 'de...  189859560
#
# [5 rows x 23 columns]

# %%
long_english_movies.shape
# Out:
# (506, 23)

# %% [markdown]
# ## <u>**Next let us see how we can manipulate columns**</u>

# %% [markdown]
# #### **Let's say if you wanted a new column whose values were half the movie runtime**

# %%
# Add new column which is just half the runtime
df['half_runtime'] = df['runtime'] * 0.5

# %%
df.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# 2  http://sonyclassics.com/whiplash/  tt2582802                en
# 3         http://kahaanithefilm.com/  tt1821480                hi
# 4                                NaN  tt1380152                ko
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                      마린보이
#
#                                             overview  popularity  ... runtime  \
# 0  When Lou, who has become the "father of the In...    6.575393  ...    93.0
# 1  Mia Thermopolis is now a college graduate and ...    8.248895  ...   113.0
# 2  Under the direction of a ruthless instructor, ...   64.299990  ...   105.0
# 3  Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936  ...   122.0
# 4  Marine Boy is the story of a former national s...    1.148070  ...   118.0
#
#                                     spoken_languages    status  \
# 0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 4           [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]  Released
#
#                                              tagline  \
# 0  The Laws of Space and Time are About to be Vio...
# 1  It can take a lifetime to find true love; she'...
# 2    The road to greatness can take you to the edge.
# 3                                                NaN
# 4                                                NaN
#
#                                       title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1  [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2  [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 3  [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 4                                                NaN
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1  [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2  [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3  [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4  [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
#
#                                                 crew   revenue half_runtime
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651         46.5
# 1  [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435         56.5
# 2  [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000         52.5
# 3  [{'credit_id': '52fe48779251416c9108d6eb', 'de...  16000000         61.0
# 4  [{'credit_id': '52fe464b9251416c75073b43', 'de...   3923970         59.0
#
# [5 rows x 24 columns]

# %%
# Creating another new column by subtracting/adding two existing columns
df['movie_profit'] = df['revenue'] - df['budget']

# %%
df.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# 2  http://sonyclassics.com/whiplash/  tt2582802                en
# 3         http://kahaanithefilm.com/  tt1821480                hi
# 4                                NaN  tt1380152                ko
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                      마린보이
#
#                                             overview  popularity  ...  \
# 0  When Lou, who has become the "father of the In...    6.575393  ...
# 1  Mia Thermopolis is now a college graduate and ...    8.248895  ...
# 2  Under the direction of a ruthless instructor, ...   64.299990  ...
# 3  Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936  ...
# 4  Marine Boy is the story of a former national s...    1.148070  ...
#
#                                     spoken_languages    status  \
# 0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 4           [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]  Released
#
#                                              tagline  \
# 0  The Laws of Space and Time are About to be Vio...
# 1  It can take a lifetime to find true love; she'...
# 2    The road to greatness can take you to the edge.
# 3                                                NaN
# 4                                                NaN
#
#                                       title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1  [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2  [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 3  [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 4                                                NaN
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1  [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2  [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3  [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4  [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
#
#                                                 crew   revenue half_runtime  \
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651         46.5
# 1  [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435         56.5
# 2  [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000         52.5
# 3  [{'credit_id': '52fe48779251416c9108d6eb', 'de...  16000000         61.0
# 4  [{'credit_id': '52fe464b9251416c75073b43', 'de...   3923970         59.0
#
#   movie_profit
# 0     -1685349
# 1     55149435
# 2      9792000
# 3     14800000
# 4      3923970
#
# [5 rows x 25 columns]

# %% [markdown]
# #### **Next, we can also drop some columns which we want to drop**

# %%
df.drop(['id'], axis = 1, inplace=True)

# %%
df.head()
# Out:
#                                belongs_to_collection    budget  \
# 0  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2                                                NaN   3300000
# 3                                                NaN   1200000
# 4                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# 2  http://sonyclassics.com/whiplash/  tt2582802                en
# 3         http://kahaanithefilm.com/  tt1821480                hi
# 4                                NaN  tt1380152                ko
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                      마린보이
#
#                                             overview  popularity  \
# 0  When Lou, who has become the "father of the In...    6.575393
# 1  Mia Thermopolis is now a college graduate and ...    8.248895
# 2  Under the direction of a ruthless instructor, ...   64.299990
# 3  Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936
# 4  Marine Boy is the story of a former national s...    1.148070
#
#                         poster_path  ...  \
# 0  /tQtWuwvMf0hCc2QR2tkolwl7c3c.jpg  ...
# 1  /w9Z7A0GHEhIp7etpj0vyKOeU1Wx.jpg  ...
# 2  /lIv1QinFqz4dlp5U4lQ6HaiskOZ.jpg  ...
# 3  /aTXRaPrWSinhcmCrcfJK17urp3F.jpg  ...
# 4  /m22s7zvkVFDU9ir56PiiqIEWFdT.jpg  ...
#
#                                     spoken_languages    status  \
# 0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 4           [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]  Released
#
#                                              tagline  \
# 0  The Laws of Space and Time are About to be Vio...
# 1  It can take a lifetime to find true love; she'...
# 2    The road to greatness can take you to the edge.
# 3                                                NaN
# 4                                                NaN
#
#                                       title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1  [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2  [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 3  [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 4                                                NaN
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1  [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2  [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3  [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4  [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
#
#                                                 crew   revenue half_runtime  \
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651         46.5
# 1  [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435         56.5
# 2  [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000         52.5
# 3  [{'credit_id': '52fe48779251416c9108d6eb', 'de...  16000000         61.0
# 4  [{'credit_id': '52fe464b9251416c75073b43', 'de...   3923970         59.0
#
#   movie_profit
# 0     -1685349
# 1     55149435
# 2      9792000
# 3     14800000
# 4      3923970
#
# [5 rows x 24 columns]

# %%
df.describe()
# Out:
#              budget   popularity      runtime       revenue  half_runtime  \
# count  3.000000e+03  3000.000000  2998.000000  3.000000e+03   2998.000000
# mean   2.253133e+07     8.463274   107.856571  6.672585e+07     53.928286
# std    3.702609e+07    12.104000    22.086434  1.375323e+08     11.043217
# min    0.000000e+00     0.000001     0.000000  1.000000e+00      0.000000
# 25%    0.000000e+00     4.018053    94.000000  2.379808e+06     47.000000
# 50%    8.000000e+06     7.374861   104.000000  1.680707e+07     52.000000
# 75%    2.900000e+07    10.890983   118.000000  6.891920e+07     59.000000
# max    3.800000e+08   294.337037   338.000000  1.519558e+09    169.000000
#
#        movie_profit
# count  3.000000e+03
# mean   4.419452e+07
# std    1.123274e+08
# min   -1.074474e+08
# 25%    1.795200e+04
# 50%    6.121122e+06
# 75%    4.143293e+07
# max    1.316249e+09

# %% [markdown]
# #### You can drop multiple columns at once too.

# %%
df.drop(['half_runtime','poster_path'],axis=1,inplace=True)

# %%
df.drop(['crew'], axis = 1, inplace=True)

# %%
df.head()
# Out:
#                                belongs_to_collection    budget  \
# 0  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2                                                NaN   3300000
# 3                                                NaN   1200000
# 4                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# 2  http://sonyclassics.com/whiplash/  tt2582802                en
# 3         http://kahaanithefilm.com/  tt1821480                hi
# 4                                NaN  tt1380152                ko
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                      마린보이
#
#                                             overview  popularity  \
# 0  When Lou, who has become the "father of the In...    6.575393
# 1  Mia Thermopolis is now a college graduate and ...    8.248895
# 2  Under the direction of a ruthless instructor, ...   64.299990
# 3  Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936
# 4  Marine Boy is the story of a former national s...    1.148070
#
#                                 production_companies  ... release_date  \
# 0  [{'name': 'Paramount Pictures', 'id': 4}, {'na...  ...      2/20/15
# 1        [{'name': 'Walt Disney Pictures', 'id': 2}]  ...       8/6/04
# 2  [{'name': 'Bold Films', 'id': 2266}, {'name': ...  ...     10/10/14
# 3                                                NaN  ...       3/9/12
# 4                                                NaN  ...       2/5/09
#
#   runtime                                   spoken_languages    status  \
# 0    93.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1   113.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2   105.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3   122.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 4   118.0           [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]  Released
#
#                                              tagline  \
# 0  The Laws of Space and Time are About to be Vio...
# 1  It can take a lifetime to find true love; she'...
# 2    The road to greatness can take you to the edge.
# 3                                                NaN
# 4                                                NaN
#
#                                       title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1  [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2  [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 3  [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 4                                                NaN
#
#                                                 cast   revenue  movie_profit
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...  12314651      -1685349
# 1  [{'cast_id': 1, 'character': 'Mia Thermopolis'...  95149435      55149435
# 2  [{'cast_id': 5, 'character': 'Andrew Neimann',...  13092000       9792000
# 3  [{'cast_id': 1, 'character': 'Vidya Bagchi', '...  16000000      14800000
# 4  [{'cast_id': 3, 'character': 'Chun-soo', 'cred...   3923970       3923970
#
# [5 rows x 21 columns]

# %% [markdown]
# ### We can do a lot of basic operations as well

# %%
# Find the sum of values in a column
df['budget'].sum()
# Out:
# 67594002330

# %%
# What if there is a null value
df.loc[:1,'revenue'] = np.nan

# %%
df.iloc[:5]
# Out:
#                                belongs_to_collection    budget  \
# 0  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2                                                NaN   3300000
# 3                                                NaN   1200000
# 4                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# 2  http://sonyclassics.com/whiplash/  tt2582802                en
# 3         http://kahaanithefilm.com/  tt1821480                hi
# 4                                NaN  tt1380152                ko
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                      마린보이
#
#                                             overview  popularity  \
# 0  When Lou, who has become the "father of the In...    6.575393
# 1  Mia Thermopolis is now a college graduate and ...    8.248895
# 2  Under the direction of a ruthless instructor, ...   64.299990
# 3  Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936
# 4  Marine Boy is the story of a former national s...    1.148070
#
#                                 production_companies  ... release_date  \
# 0  [{'name': 'Paramount Pictures', 'id': 4}, {'na...  ...      2/20/15
# 1        [{'name': 'Walt Disney Pictures', 'id': 2}]  ...       8/6/04
# 2  [{'name': 'Bold Films', 'id': 2266}, {'name': ...  ...     10/10/14
# 3                                                NaN  ...       3/9/12
# 4                                                NaN  ...       2/5/09
#
#   runtime                                   spoken_languages    status  \
# 0    93.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1   113.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2   105.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3   122.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 4   118.0           [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]  Released
#
#                                              tagline  \
# 0  The Laws of Space and Time are About to be Vio...
# 1  It can take a lifetime to find true love; she'...
# 2    The road to greatness can take you to the edge.
# 3                                                NaN
# 4                                                NaN
#
#                                       title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1  [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2  [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 3  [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 4                                                NaN
#
#                                                 cast     revenue  movie_profit
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...         NaN      -1685349
# 1  [{'cast_id': 1, 'character': 'Mia Thermopolis'...         NaN      55149435
# 2  [{'cast_id': 5, 'character': 'Andrew Neimann',...  13092000.0       9792000
# 3  [{'cast_id': 1, 'character': 'Vidya Bagchi', '...  16000000.0      14800000
# 4  [{'cast_id': 3, 'character': 'Chun-soo', 'cred...   3923970.0       3923970
#
# [5 rows x 21 columns]

# %%
df.set_index('imdb_id', inplace=True)

# %%
df.head()
# Out:
#                                        belongs_to_collection    budget  \
# imdb_id
# tt2637294  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# tt0368933  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# tt2582802                                                NaN   3300000
# tt1821480                                                NaN   1200000
# tt1380152                                                NaN         0
#
#                                                       genres  \
# imdb_id
# tt2637294                     [{'id': 35, 'name': 'Comedy'}]
# tt0368933  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# tt2582802                      [{'id': 18, 'name': 'Drama'}]
# tt1821480  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# tt1380152  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                                     homepage original_language  \
# imdb_id
# tt2637294                                NaN                en
# tt0368933                                NaN                en
# tt2582802  http://sonyclassics.com/whiplash/                en
# tt1821480         http://kahaanithefilm.com/                hi
# tt1380152                                NaN                ko
#
#                                      original_title  \
# imdb_id
# tt2637294                    Hot Tub Time Machine 2
# tt0368933  The Princess Diaries 2: Royal Engagement
# tt2582802                                  Whiplash
# tt1821480                                   Kahaani
# tt1380152                                      마린보이
#
#                                                     overview  popularity  \
# imdb_id
# tt2637294  When Lou, who has become the "father of the In...    6.575393
# tt0368933  Mia Thermopolis is now a college graduate and ...    8.248895
# tt2582802  Under the direction of a ruthless instructor, ...   64.299990
# tt1821480  Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936
# tt1380152  Marine Boy is the story of a former national s...    1.148070
#
#                                         production_companies  \
# imdb_id
# tt2637294  [{'name': 'Paramount Pictures', 'id': 4}, {'na...
# tt0368933        [{'name': 'Walt Disney Pictures', 'id': 2}]
# tt2582802  [{'name': 'Bold Films', 'id': 2266}, {'name': ...
# tt1821480                                                NaN
# tt1380152                                                NaN
#
#                                         production_countries release_date  \
# imdb_id
# tt2637294  [{'iso_3166_1': 'US', 'name': 'United States o...      2/20/15
# tt0368933  [{'iso_3166_1': 'US', 'name': 'United States o...       8/6/04
# tt2582802  [{'iso_3166_1': 'US', 'name': 'United States o...     10/10/14
# tt1821480            [{'iso_3166_1': 'IN', 'name': 'India'}]       3/9/12
# tt1380152      [{'iso_3166_1': 'KR', 'name': 'South Korea'}]       2/5/09
#
#            runtime                                   spoken_languages  \
# imdb_id
# tt2637294     93.0           [{'iso_639_1': 'en', 'name': 'English'}]
# tt0368933    113.0           [{'iso_639_1': 'en', 'name': 'English'}]
# tt2582802    105.0           [{'iso_639_1': 'en', 'name': 'English'}]
# tt1821480    122.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# tt1380152    118.0           [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]
#
#              status                                            tagline  \
# imdb_id
# tt2637294  Released  The Laws of Space and Time are About to be Vio...
# tt0368933  Released  It can take a lifetime to find true love; she'...
# tt2582802  Released    The road to greatness can take you to the edge.
# tt1821480  Released                                                NaN
# tt1380152  Released                                                NaN
#
#                                               title  \
# imdb_id
# tt2637294                    Hot Tub Time Machine 2
# tt0368933  The Princess Diaries 2: Royal Engagement
# tt2582802                                  Whiplash
# tt1821480                                   Kahaani
# tt1380152                                Marine Boy
#
#                                                     Keywords  \
# imdb_id
# tt2637294  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# tt0368933  [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# tt2582802  [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# tt1821480  [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# tt1380152                                                NaN
#
#                                                         cast     revenue  \
# imdb_id
# tt2637294  [{'cast_id': 4, 'character': 'Lou', 'credit_id...         NaN
# tt0368933  [{'cast_id': 1, 'character': 'Mia Thermopolis'...         NaN
# tt2582802  [{'cast_id': 5, 'character': 'Andrew Neimann',...  13092000.0
# tt1821480  [{'cast_id': 1, 'character': 'Vidya Bagchi', '...  16000000.0
# tt1380152  [{'cast_id': 3, 'character': 'Chun-soo', 'cred...   3923970.0
#
#            movie_profit
# imdb_id
# tt2637294      -1685349
# tt0368933      55149435
# tt2582802       9792000
# tt1821480      14800000
# tt1380152       3923970

# %%
df.iloc[:3]
# Out:
#                                        belongs_to_collection    budget  \
# imdb_id
# tt2637294  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# tt0368933  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# tt2582802                                                NaN   3300000
#
#                                                       genres  \
# imdb_id
# tt2637294                     [{'id': 35, 'name': 'Comedy'}]
# tt0368933  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# tt2582802                      [{'id': 18, 'name': 'Drama'}]
#
#                                     homepage original_language  \
# imdb_id
# tt2637294                                NaN                en
# tt0368933                                NaN                en
# tt2582802  http://sonyclassics.com/whiplash/                en
#
#                                      original_title  \
# imdb_id
# tt2637294                    Hot Tub Time Machine 2
# tt0368933  The Princess Diaries 2: Royal Engagement
# tt2582802                                  Whiplash
#
#                                                     overview  popularity  \
# imdb_id
# tt2637294  When Lou, who has become the "father of the In...    6.575393
# tt0368933  Mia Thermopolis is now a college graduate and ...    8.248895
# tt2582802  Under the direction of a ruthless instructor, ...   64.299990
#
#                                         production_companies  \
# imdb_id
# tt2637294  [{'name': 'Paramount Pictures', 'id': 4}, {'na...
# tt0368933        [{'name': 'Walt Disney Pictures', 'id': 2}]
# tt2582802  [{'name': 'Bold Films', 'id': 2266}, {'name': ...
#
#                                         production_countries release_date  \
# imdb_id
# tt2637294  [{'iso_3166_1': 'US', 'name': 'United States o...      2/20/15
# tt0368933  [{'iso_3166_1': 'US', 'name': 'United States o...       8/6/04
# tt2582802  [{'iso_3166_1': 'US', 'name': 'United States o...     10/10/14
#
#            runtime                          spoken_languages    status  \
# imdb_id
# tt2637294     93.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# tt0368933    113.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# tt2582802    105.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                      tagline  \
# imdb_id
# tt2637294  The Laws of Space and Time are About to be Vio...
# tt0368933  It can take a lifetime to find true love; she'...
# tt2582802    The road to greatness can take you to the edge.
#
#                                               title  \
# imdb_id
# tt2637294                    Hot Tub Time Machine 2
# tt0368933  The Princess Diaries 2: Royal Engagement
# tt2582802                                  Whiplash
#
#                                                     Keywords  \
# imdb_id
# tt2637294  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# tt0368933  [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# tt2582802  [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
#
#                                                         cast     revenue  \
# imdb_id
# tt2637294  [{'cast_id': 4, 'character': 'Lou', 'credit_id...         NaN
# tt0368933  [{'cast_id': 1, 'character': 'Mia Thermopolis'...         NaN
# tt2582802  [{'cast_id': 5, 'character': 'Andrew Neimann',...  13092000.0
#
#            movie_profit
# imdb_id
# tt2637294      -1685349
# tt0368933      55149435
# tt2582802       9792000

# %%
df.loc[['tt2637294','tt0368933']]
# Out:
#                                        belongs_to_collection    budget  \
# imdb_id
# tt2637294  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# tt0368933  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
#
#                                                       genres homepage  \
# imdb_id
# tt2637294                     [{'id': 35, 'name': 'Comedy'}]      NaN
# tt0368933  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...      NaN
#
#           original_language                            original_title  \
# imdb_id
# tt2637294                en                    Hot Tub Time Machine 2
# tt0368933                en  The Princess Diaries 2: Royal Engagement
#
#                                                     overview  popularity  \
# imdb_id
# tt2637294  When Lou, who has become the "father of the In...    6.575393
# tt0368933  Mia Thermopolis is now a college graduate and ...    8.248895
#
#                                         production_companies  \
# imdb_id
# tt2637294  [{'name': 'Paramount Pictures', 'id': 4}, {'na...
# tt0368933        [{'name': 'Walt Disney Pictures', 'id': 2}]
#
#                                         production_countries release_date  \
# imdb_id
# tt2637294  [{'iso_3166_1': 'US', 'name': 'United States o...      2/20/15
# tt0368933  [{'iso_3166_1': 'US', 'name': 'United States o...       8/6/04
#
#            runtime                          spoken_languages    status  \
# imdb_id
# tt2637294     93.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# tt0368933    113.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                      tagline  \
# imdb_id
# tt2637294  The Laws of Space and Time are About to be Vio...
# tt0368933  It can take a lifetime to find true love; she'...
#
#                                               title  \
# imdb_id
# tt2637294                    Hot Tub Time Machine 2
# tt0368933  The Princess Diaries 2: Royal Engagement
#
#                                                     Keywords  \
# imdb_id
# tt2637294  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# tt0368933  [{'id': 2505, 'name': 'coronation'}, {'id': 42...
#
#                                                         cast  revenue  \
# imdb_id
# tt2637294  [{'cast_id': 4, 'character': 'Lou', 'credit_id...      NaN
# tt0368933  [{'cast_id': 1, 'character': 'Mia Thermopolis'...      NaN
#
#            movie_profit
# imdb_id
# tt2637294      -1685349
# tt0368933      55149435

# %%
df.head()
# Out:
#                                        belongs_to_collection    budget  \
# imdb_id
# tt2637294  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# tt0368933  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# tt2582802                                                NaN   3300000
# tt1821480                                                NaN   1200000
# tt1380152                                                NaN         0
#
#                                                       genres  \
# imdb_id
# tt2637294                     [{'id': 35, 'name': 'Comedy'}]
# tt0368933  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# tt2582802                      [{'id': 18, 'name': 'Drama'}]
# tt1821480  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# tt1380152  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                                     homepage original_language  \
# imdb_id
# tt2637294                                NaN                en
# tt0368933                                NaN                en
# tt2582802  http://sonyclassics.com/whiplash/                en
# tt1821480         http://kahaanithefilm.com/                hi
# tt1380152                                NaN                ko
#
#                                      original_title  \
# imdb_id
# tt2637294                    Hot Tub Time Machine 2
# tt0368933  The Princess Diaries 2: Royal Engagement
# tt2582802                                  Whiplash
# tt1821480                                   Kahaani
# tt1380152                                      마린보이
#
#                                                     overview  popularity  \
# imdb_id
# tt2637294  When Lou, who has become the "father of the In...    6.575393
# tt0368933  Mia Thermopolis is now a college graduate and ...    8.248895
# tt2582802  Under the direction of a ruthless instructor, ...   64.299990
# tt1821480  Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936
# tt1380152  Marine Boy is the story of a former national s...    1.148070
#
#                                         production_companies  \
# imdb_id
# tt2637294  [{'name': 'Paramount Pictures', 'id': 4}, {'na...
# tt0368933        [{'name': 'Walt Disney Pictures', 'id': 2}]
# tt2582802  [{'name': 'Bold Films', 'id': 2266}, {'name': ...
# tt1821480                                                NaN
# tt1380152                                                NaN
#
#                                         production_countries release_date  \
# imdb_id
# tt2637294  [{'iso_3166_1': 'US', 'name': 'United States o...      2/20/15
# tt0368933  [{'iso_3166_1': 'US', 'name': 'United States o...       8/6/04
# tt2582802  [{'iso_3166_1': 'US', 'name': 'United States o...     10/10/14
# tt1821480            [{'iso_3166_1': 'IN', 'name': 'India'}]       3/9/12
# tt1380152      [{'iso_3166_1': 'KR', 'name': 'South Korea'}]       2/5/09
#
#            runtime                                   spoken_languages  \
# imdb_id
# tt2637294     93.0           [{'iso_639_1': 'en', 'name': 'English'}]
# tt0368933    113.0           [{'iso_639_1': 'en', 'name': 'English'}]
# tt2582802    105.0           [{'iso_639_1': 'en', 'name': 'English'}]
# tt1821480    122.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# tt1380152    118.0           [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]
#
#              status                                            tagline  \
# imdb_id
# tt2637294  Released  The Laws of Space and Time are About to be Vio...
# tt0368933  Released  It can take a lifetime to find true love; she'...
# tt2582802  Released    The road to greatness can take you to the edge.
# tt1821480  Released                                                NaN
# tt1380152  Released                                                NaN
#
#                                               title  \
# imdb_id
# tt2637294                    Hot Tub Time Machine 2
# tt0368933  The Princess Diaries 2: Royal Engagement
# tt2582802                                  Whiplash
# tt1821480                                   Kahaani
# tt1380152                                Marine Boy
#
#                                                     Keywords  \
# imdb_id
# tt2637294  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# tt0368933  [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# tt2582802  [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# tt1821480  [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# tt1380152                                                NaN
#
#                                                         cast     revenue  \
# imdb_id
# tt2637294  [{'cast_id': 4, 'character': 'Lou', 'credit_id...         NaN
# tt0368933  [{'cast_id': 1, 'character': 'Mia Thermopolis'...         NaN
# tt2582802  [{'cast_id': 5, 'character': 'Andrew Neimann',...  13092000.0
# tt1821480  [{'cast_id': 1, 'character': 'Vidya Bagchi', '...  16000000.0
# tt1380152  [{'cast_id': 3, 'character': 'Chun-soo', 'cred...   3923970.0
#
#            movie_profit
# imdb_id
# tt2637294      -1685349
# tt0368933      55149435
# tt2582802       9792000
# tt1821480      14800000
# tt1380152       3923970

# %%
df['runtime'].sum()
# Out:
# 323354.0

# %%
print(f" The shortest movie length is {df['runtime'].min()}")
print(f" The largest movie length is {df['runtime'].max()}")
# Out:
#  The shortest movie length is 0.0
#  The largest movie length is 338.0

# %%
df[df['runtime']== 0.0]
# Out:
#                                        belongs_to_collection    budget  \
# imdb_id
# tt2550838                                                NaN   6843500
# tt0768690                                                NaN         0
# tt2604346                                                NaN         0
# tt2076251                                                NaN  11000000
# tt0072785                                                NaN         0
# tt3805180                                                NaN    750000
# tt1133617                                                NaN         0
# tt0477337                                                NaN   5000000
# tt1620549  [{'id': 106790, 'name': 'Hooked Collection', '...   3500000
# tt3956312                                                NaN         0
# tt0278675                                                NaN         0
# tt2456720  [{'id': 188197, 'name': 'Cetto La Qualunque - ...   5579750
#
#                                                       genres  \
# imdb_id
# tt2550838                     [{'id': 35, 'name': 'Comedy'}]
# tt0768690  [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...
# tt2604346                     [{'id': 35, 'name': 'Comedy'}]
# tt2076251                     [{'id': 35, 'name': 'Comedy'}]
# tt0072785                    [{'id': 37, 'name': 'Western'}]
# tt3805180  [{'id': 80, 'name': 'Crime'}, {'id': 35, 'name...
# tt1133617  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# tt0477337  [{'id': 28, 'name': 'Action'}, {'id': 10749, '...
# tt1620549  [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
# tt3956312                 [{'id': 10749, 'name': 'Romance'}]
# tt0278675  [{'id': 14, 'name': 'Fantasy'}, {'id': 27, 'na...
# tt2456720                     [{'id': 35, 'name': 'Comedy'}]
#
#                             homepage original_language  \
# imdb_id
# tt2550838                        NaN                it
# tt0768690                        NaN                ru
# tt2604346                        NaN                es
# tt2076251                        NaN                it
# tt0072785                        NaN                it
# tt3805180                        NaN                ru
# tt1133617  http://www.vt4.be/vermist                en
# tt0477337                        NaN                ru
# tt1620549                        NaN                ru
# tt3956312                        NaN                en
# tt0278675                        NaN                fr
# tt2456720                        NaN                it
#
#                                 original_title  \
# imdb_id
# tt2550838     Il peggior Natale della mia vita
# tt0768690              А поутру они проснулись
# tt2604346                 ¿Quién mató a Bambi?
# tt2076251  La peggior settimana della mia vita
# tt0072785                         Cipolla Colt
# tt3805180                          Все и сразу
# tt1133617                              Vermist
# tt0477337                          Mechenosets
# tt1620549              Na Igre 2. Novyy Uroven
# tt3956312                                 同桌的妳
# tt0278675                           Revelation
# tt2456720            Tutto tutto niente niente
#
#                                                     overview  popularity  \
# imdb_id
# tt2550838                                                NaN    3.800073
# tt0768690                                                NaN    0.402368
# tt2604346  It tells the story of two young friends who mu...    1.926826
# tt2076251                                                NaN    5.010563
# tt0072785  Onion Jack (Franco Nero) has bought a piece of...    1.623440
# tt3805180                                                NaN    0.201582
# tt1133617  Five members of the Missing Persons Task Force...    0.229233
# tt0477337                                                NaN    0.414793
# tt1620549  The continuation of the adventures of the hero...    0.884241
# tt3956312  In the summer of 1993, timid and shy Zhou Xiao...    0.504000
# tt0278675  Since A.D. 50, a mysterious sacred artifact kn...    0.625099
# tt2456720                                                NaN    2.208906
#
#                                         production_companies  \
# imdb_id
# tt2550838  [{'name': 'Colorado Film Production', 'id': 10...
# tt0768690  [{'name': 'Роскинопрокат', 'id': 14650}, {'nam...
# tt2604346  [{'name': 'Televisión Española (TVE)', 'id': 6...
# tt2076251  [{'name': 'Colorado Film Production', 'id': 10...
# tt0072785  [{'name': 'Compagnia Cinematografica Champion'...
# tt3805180  [{'name': 'Кинокомпания «Lunapark»', 'id': 420...
# tt1133617                                                NaN
# tt0477337         [{'name': 'Kinokompaniya CTB', 'id': 886}]
# tt1620549                                                NaN
# tt3956312         [{'name': 'Enlight Pictures', 'id': 4053}]
# tt0278675  [{'name': 'Romulus Films', 'id': 3632}, {'name...
# tt2456720  [{'name': 'Fandango', 'id': 2441}, {'name': 'R...
#
#                                         production_countries release_date  \
# imdb_id
# tt2550838            [{'iso_3166_1': 'IT', 'name': 'Italy'}]     12/22/12
# tt0768690           [{'iso_3166_1': 'RU', 'name': 'Russia'}]      12/4/03
# tt2604346            [{'iso_3166_1': 'ES', 'name': 'Spain'}]     11/15/13
# tt2076251            [{'iso_3166_1': 'IT', 'name': 'Italy'}]     10/27/11
# tt0072785  [{'iso_3166_1': 'IT', 'name': 'Italy'}, {'iso_...      8/25/75
# tt3805180           [{'iso_3166_1': 'RU', 'name': 'Russia'}]       6/5/14
# tt1133617          [{'iso_3166_1': 'BE', 'name': 'Belgium'}]       1/1/07
# tt0477337           [{'iso_3166_1': 'RU', 'name': 'Russia'}]     10/12/06
# tt1620549           [{'iso_3166_1': 'RU', 'name': 'Russia'}]      4/15/10
# tt3956312            [{'iso_3166_1': 'CN', 'name': 'China'}]      4/25/14
# tt0278675   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]      4/12/01
# tt2456720            [{'iso_3166_1': 'IT', 'name': 'Italy'}]     11/30/12
#
#            runtime                             spoken_languages    status  \
# imdb_id
# tt2550838      0.0    [{'iso_639_1': 'it', 'name': 'Italiano'}]  Released
# tt0768690      0.0     [{'iso_639_1': 'ru', 'name': 'Pусский'}]  Released
# tt2604346      0.0     [{'iso_639_1': 'es', 'name': 'Español'}]  Released
# tt2076251      0.0    [{'iso_639_1': 'it', 'name': 'Italiano'}]  Released
# tt0072785      0.0     [{'iso_639_1': 'en', 'name': 'English'}]  Released
# tt3805180      0.0     [{'iso_639_1': 'ru', 'name': 'Pусский'}]  Released
# tt1133617      0.0  [{'iso_639_1': 'nl', 'name': 'Nederlands'}]  Released
# tt0477337      0.0     [{'iso_639_1': 'ru', 'name': 'Pусский'}]  Released
# tt1620549      0.0     [{'iso_639_1': 'ru', 'name': 'Pусский'}]  Released
# tt3956312      0.0         [{'iso_639_1': 'zh', 'name': '普通话'}]  Released
# tt0278675      0.0                                          NaN  Released
# tt2456720      0.0    [{'iso_639_1': 'it', 'name': 'Italiano'}]  Released
#
#           tagline                                 title  \
# imdb_id
# tt2550838     NaN        The Worst Christmas of My Life
# tt0768690     NaN               А поутру они проснулись
# tt2604346     NaN                  ¿Quién mató a Bambi?
# tt2076251     NaN   La peggior settimana della mia vita
# tt0072785     NaN                           Cry, Onion!
# tt3805180     NaN                           All at Once
# tt1133617     NaN                               Missing
# tt0477337     NaN                           Mechenosets
# tt1620549     NaN  Hooked on the Game 2. The Next Level
# tt3956312     NaN                      My Old Classmate
# tt0278675     NaN                            Revelation
# tt2456720     NaN             Tutto tutto niente niente
#
#                                                     Keywords  \
# imdb_id
# tt2550838                                                NaN
# tt0768690  [{'id': 4897, 'name': 'multiple character'}, {...
# tt2604346  [{'id': 1930, 'name': 'kidnapping'}, {'id': 97...
# tt2076251                                                NaN
# tt0072785      [{'id': 156212, 'name': 'spaghetti western'}]
# tt3805180  [{'id': 642, 'name': 'robbery'}, {'id': 231149...
# tt1133617                                                NaN
# tt0477337                                                NaN
# tt1620549                                                NaN
# tt3956312                                                NaN
# tt0278675                                                NaN
# tt2456720  [{'id': 8201, 'name': 'satire'}, {'id': 33501,...
#
#                                                         cast     revenue  \
# imdb_id
# tt2550838  [{'cast_id': 2, 'character': 'Alberto', 'credi...  10703234.0
# tt0768690  [{'cast_id': 8, 'character': '', 'credit_id': ...    234748.0
# tt2604346  [{'cast_id': 3, 'character': 'David', 'credit_...    850259.0
# tt2076251  [{'cast_id': 4, 'character': 'Paolo', 'credit_...  12935800.0
# tt0072785  [{'cast_id': 14, 'character': 'Onion Stark', '...  39598448.0
# tt3805180  [{'cast_id': 3, 'character': 'Viktor', 'credit...         3.0
# tt1133617  [{'cast_id': 2, 'character': 'Murat Hoxha', 'c...         1.0
# tt0477337  [{'cast_id': 2, 'character': 'Sasha', 'credit_...   3919731.0
# tt1620549  [{'cast_id': 10, 'character': 'Vampire', 'cred...   2294357.0
# tt3956312  [{'cast_id': 0, 'character': 'Zhou Xiao Zhi', ...  76000000.0
# tt0278675  [{'cast_id': 1, 'character': 'Jake Martel', 'c...  10000000.0
# tt2456720  [{'cast_id': 1, 'character': 'Cetto La Qualunq...   8927600.0
#
#            movie_profit
# imdb_id
# tt2550838       3859734
# tt0768690        234748
# tt2604346        850259
# tt2076251       1935800
# tt0072785      39598448
# tt3805180       -749997
# tt1133617             1
# tt0477337      -1080269
# tt1620549      -1205643
# tt3956312      76000000
# tt0278675      10000000
# tt2456720       3347850

# %% [markdown]
# ### **<code>apply()</code>** method applies a function to every row in a pandas dataframe

# %%
# Suppose we want to convert the column network to uppercase

def to_uppercase(column):
  return column.upper()
df['Capitalized_title'] = df['title'].apply(to_uppercase)

# %%
df.head()
# Out:
#                                        belongs_to_collection    budget  \
# imdb_id
# tt2637294  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# tt0368933  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# tt2582802                                                NaN   3300000
# tt1821480                                                NaN   1200000
# tt1380152                                                NaN         0
#
#                                                       genres  \
# imdb_id
# tt2637294                     [{'id': 35, 'name': 'Comedy'}]
# tt0368933  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# tt2582802                      [{'id': 18, 'name': 'Drama'}]
# tt1821480  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# tt1380152  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                                     homepage original_language  \
# imdb_id
# tt2637294                                NaN                en
# tt0368933                                NaN                en
# tt2582802  http://sonyclassics.com/whiplash/                en
# tt1821480         http://kahaanithefilm.com/                hi
# tt1380152                                NaN                ko
#
#                                      original_title  \
# imdb_id
# tt2637294                    Hot Tub Time Machine 2
# tt0368933  The Princess Diaries 2: Royal Engagement
# tt2582802                                  Whiplash
# tt1821480                                   Kahaani
# tt1380152                                      마린보이
#
#                                                     overview  popularity  \
# imdb_id
# tt2637294  When Lou, who has become the "father of the In...    6.575393
# tt0368933  Mia Thermopolis is now a college graduate and ...    8.248895
# tt2582802  Under the direction of a ruthless instructor, ...   64.299990
# tt1821480  Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936
# tt1380152  Marine Boy is the story of a former national s...    1.148070
#
#                                         production_companies  \
# imdb_id
# tt2637294  [{'name': 'Paramount Pictures', 'id': 4}, {'na...
# tt0368933        [{'name': 'Walt Disney Pictures', 'id': 2}]
# tt2582802  [{'name': 'Bold Films', 'id': 2266}, {'name': ...
# tt1821480                                                NaN
# tt1380152                                                NaN
#
#                                         production_countries  ... runtime  \
# imdb_id                                                       ...
# tt2637294  [{'iso_3166_1': 'US', 'name': 'United States o...  ...    93.0
# tt0368933  [{'iso_3166_1': 'US', 'name': 'United States o...  ...   113.0
# tt2582802  [{'iso_3166_1': 'US', 'name': 'United States o...  ...   105.0
# tt1821480            [{'iso_3166_1': 'IN', 'name': 'India'}]  ...   122.0
# tt1380152      [{'iso_3166_1': 'KR', 'name': 'South Korea'}]  ...   118.0
#
#                                             spoken_languages    status  \
# imdb_id
# tt2637294           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# tt0368933           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# tt2582802           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# tt1821480  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# tt1380152           [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]  Released
#
#                                                      tagline  \
# imdb_id
# tt2637294  The Laws of Space and Time are About to be Vio...
# tt0368933  It can take a lifetime to find true love; she'...
# tt2582802    The road to greatness can take you to the edge.
# tt1821480                                                NaN
# tt1380152                                                NaN
#
#                                               title  \
# imdb_id
# tt2637294                    Hot Tub Time Machine 2
# tt0368933  The Princess Diaries 2: Royal Engagement
# tt2582802                                  Whiplash
# tt1821480                                   Kahaani
# tt1380152                                Marine Boy
#
#                                                     Keywords  \
# imdb_id
# tt2637294  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# tt0368933  [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# tt2582802  [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# tt1821480  [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# tt1380152                                                NaN
#
#                                                         cast     revenue  \
# imdb_id
# tt2637294  [{'cast_id': 4, 'character': 'Lou', 'credit_id...         NaN
# tt0368933  [{'cast_id': 1, 'character': 'Mia Thermopolis'...         NaN
# tt2582802  [{'cast_id': 5, 'character': 'Andrew Neimann',...  13092000.0
# tt1821480  [{'cast_id': 1, 'character': 'Vidya Bagchi', '...  16000000.0
# tt1380152  [{'cast_id': 3, 'character': 'Chun-soo', 'cred...   3923970.0
#
#            movie_profit                         Capitalized_title
# imdb_id
# tt2637294      -1685349                    HOT TUB TIME MACHINE 2
# tt0368933      55149435  THE PRINCESS DIARIES 2: ROYAL ENGAGEMENT
# tt2582802       9792000                                  WHIPLASH
# tt1821480      14800000                                   KAHAANI
# tt1380152       3923970                                MARINE BOY
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Another way to use <code>apply()</code> involves the use of <code>lambda()</code> function.
#
# * A <code>lambda()</code> function is a small anonymous function.
# * A <code>lambda()</code> function can take any number of arguments, but can only have one expression.

# %%
def add_two_numbers(a,b):
  return a+b

# %%
x = lambda a,b : a+b
x(1,5)
# Out:
# 6

# %%
# lambda function - Row wise operation
def revised_profit(revenue, budget):
  if revenue > 0:
    new_profit = revenue - budget
  else:
    new_profit = np.nan
    
  return new_profit

# %%
df['new_profit'] = df.apply(lambda x: revised_profit(x['revenue'], x['budget']),axis=1)

# %%
df.head()
# Out:
#                                        belongs_to_collection    budget  \
# imdb_id
# tt2637294  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# tt0368933  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# tt2582802                                                NaN   3300000
# tt1821480                                                NaN   1200000
# tt1380152                                                NaN         0
#
#                                                       genres  \
# imdb_id
# tt2637294                     [{'id': 35, 'name': 'Comedy'}]
# tt0368933  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# tt2582802                      [{'id': 18, 'name': 'Drama'}]
# tt1821480  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# tt1380152  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                                     homepage original_language  \
# imdb_id
# tt2637294                                NaN                en
# tt0368933                                NaN                en
# tt2582802  http://sonyclassics.com/whiplash/                en
# tt1821480         http://kahaanithefilm.com/                hi
# tt1380152                                NaN                ko
#
#                                      original_title  \
# imdb_id
# tt2637294                    Hot Tub Time Machine 2
# tt0368933  The Princess Diaries 2: Royal Engagement
# tt2582802                                  Whiplash
# tt1821480                                   Kahaani
# tt1380152                                      마린보이
#
#                                                     overview  popularity  \
# imdb_id
# tt2637294  When Lou, who has become the "father of the In...    6.575393
# tt0368933  Mia Thermopolis is now a college graduate and ...    8.248895
# tt2582802  Under the direction of a ruthless instructor, ...   64.299990
# tt1821480  Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936
# tt1380152  Marine Boy is the story of a former national s...    1.148070
#
#                                         production_companies  \
# imdb_id
# tt2637294  [{'name': 'Paramount Pictures', 'id': 4}, {'na...
# tt0368933        [{'name': 'Walt Disney Pictures', 'id': 2}]
# tt2582802  [{'name': 'Bold Films', 'id': 2266}, {'name': ...
# tt1821480                                                NaN
# tt1380152                                                NaN
#
#                                         production_countries  ...  \
# imdb_id                                                       ...
# tt2637294  [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# tt0368933  [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# tt2582802  [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# tt1821480            [{'iso_3166_1': 'IN', 'name': 'India'}]  ...
# tt1380152      [{'iso_3166_1': 'KR', 'name': 'South Korea'}]  ...
#
#                                             spoken_languages    status  \
# imdb_id
# tt2637294           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# tt0368933           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# tt2582802           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# tt1821480  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# tt1380152           [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]  Released
#
#                                                      tagline  \
# imdb_id
# tt2637294  The Laws of Space and Time are About to be Vio...
# tt0368933  It can take a lifetime to find true love; she'...
# tt2582802    The road to greatness can take you to the edge.
# tt1821480                                                NaN
# tt1380152                                                NaN
#
#                                               title  \
# imdb_id
# tt2637294                    Hot Tub Time Machine 2
# tt0368933  The Princess Diaries 2: Royal Engagement
# tt2582802                                  Whiplash
# tt1821480                                   Kahaani
# tt1380152                                Marine Boy
#
#                                                     Keywords  \
# imdb_id
# tt2637294  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# tt0368933  [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# tt2582802  [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# tt1821480  [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# tt1380152                                                NaN
#
#                                                         cast     revenue  \
# imdb_id
# tt2637294  [{'cast_id': 4, 'character': 'Lou', 'credit_id...         NaN
# tt0368933  [{'cast_id': 1, 'character': 'Mia Thermopolis'...         NaN
# tt2582802  [{'cast_id': 5, 'character': 'Andrew Neimann',...  13092000.0
# tt1821480  [{'cast_id': 1, 'character': 'Vidya Bagchi', '...  16000000.0
# tt1380152  [{'cast_id': 3, 'character': 'Chun-soo', 'cred...   3923970.0
#
#           movie_profit                         Capitalized_title  new_profit
# imdb_id
# tt2637294     -1685349                    HOT TUB TIME MACHINE 2         NaN
# tt0368933     55149435  THE PRINCESS DIARIES 2: ROYAL ENGAGEMENT         NaN
# tt2582802      9792000                                  WHIPLASH   9792000.0
# tt1821480     14800000                                   KAHAANI  14800000.0
# tt1380152      3923970                                MARINE BOY   3923970.0
#
# [5 rows x 22 columns]

# %%
# Sort values in descending order
df.sort_values('runtime', ascending=False)
# Out:
#                                        belongs_to_collection    budget  \
# imdb_id
# tt1321865                                                NaN  18000000
# tt0056937                                                NaN  31115000
# tt0049833                                                NaN  13000000
# tt0080855                                                NaN  44000000
# tt0279111                                                NaN  56000000
# ...                                                      ...       ...
# tt0278675                                                NaN         0
# tt2456720  [{'id': 188197, 'name': 'Cetto La Qualunque - ...   5579750
# tt1620549  [{'id': 106790, 'name': 'Hooked Collection', '...   3500000
# tt1107828                                                NaN   6000000
# tt0116485                                                NaN         0
#
#                                                       genres homepage  \
# imdb_id
# tt1321865  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...      NaN
# tt0056937  [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...      NaN
# tt0049833  [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...      NaN
# tt0080855  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...      NaN
# tt0279111  [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...      NaN
# ...                                                      ...      ...
# tt0278675  [{'id': 14, 'name': 'Fantasy'}, {'id': 27, 'na...      NaN
# tt2456720                     [{'id': 35, 'name': 'Comedy'}]      NaN
# tt1620549  [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...      NaN
# tt1107828                      [{'id': 18, 'name': 'Drama'}]      NaN
# tt0116485                     [{'id': 35, 'name': 'Comedy'}]      NaN
#
#           original_language             original_title  \
# imdb_id
# tt1321865                en                     Carlos
# tt0056937                en                  Cleopatra
# tt0049833                en       The Ten Commandments
# tt0080855                en              Heaven's Gate
# tt0279111                en          Gods and Generals
# ...                     ...                        ...
# tt0278675                fr                 Revelation
# tt2456720                it  Tutto tutto niente niente
# tt1620549                ru    Na Igre 2. Novyy Uroven
# tt1107828                ru                    Королёв
# tt0116485                de              Happy Weekend
#
#                                                     overview  popularity  \
# imdb_id
# tt1321865  The story of Venezuelan revolutionary, Ilich R...    4.558075
# tt0056937  Historical epic. The triumphs and tragedy of t...    8.591238
# tt0049833  Escaping death, a Hebrew infant is raised in a...   11.147040
# tt0080855  Harvard graduate James Averill (Kris Kristoffe...    4.393576
# tt0279111  The film centers mostly around the personal an...    5.374563
# ...                                                      ...         ...
# tt0278675  Since A.D. 50, a mysterious sacred artifact kn...    0.625099
# tt2456720                                                NaN    2.208906
# tt1620549  The continuation of the adventures of the hero...    0.884241
# tt1107828                                                NaN    0.292296
# tt0116485                                                NaN    0.002229
#
#                                         production_companies  \
# imdb_id
# tt1321865  [{'name': 'Egoli Tossell Film AG', 'id': 2254}...
# tt0056937  [{'name': 'Twentieth Century Fox Film Corporat...
# tt0049833  [{'name': 'Paramount Pictures', 'id': 4}, {'na...
# tt0080855  [{'name': 'United Artists', 'id': 60}, {'name'...
# tt0279111  [{'name': 'Warner Bros. Pictures', 'id': 174},...
# ...                                                      ...
# tt0278675  [{'name': 'Romulus Films', 'id': 3632}, {'name...
# tt2456720  [{'name': 'Fandango', 'id': 2441}, {'name': 'R...
# tt1620549                                                NaN
# tt1107828                                                NaN
# tt0116485   [{'name': 'Senator Film Produktion', 'id': 191}]
#
#                                         production_countries  ...  \
# imdb_id                                                       ...
# tt1321865  [{'iso_3166_1': 'FR', 'name': 'France'}, {'iso...  ...
# tt0056937  [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...  ...
# tt0049833  [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# tt0080855  [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# tt0279111  [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# ...                                                      ...  ...
# tt0278675   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]  ...
# tt2456720            [{'iso_3166_1': 'IT', 'name': 'Italy'}]  ...
# tt1620549           [{'iso_3166_1': 'RU', 'name': 'Russia'}]  ...
# tt1107828                                                NaN  ...
# tt0116485          [{'iso_3166_1': 'DE', 'name': 'Germany'}]  ...
#
#                                             spoken_languages    status  \
# imdb_id
# tt1321865  [{'iso_639_1': 'fr', 'name': 'Français'}, {'is...  Released
# tt0056937  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# tt0049833           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# tt0080855  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# tt0279111           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# ...                                                      ...       ...
# tt0278675                                                NaN  Released
# tt2456720          [{'iso_639_1': 'it', 'name': 'Italiano'}]  Released
# tt1620549           [{'iso_639_1': 'ru', 'name': 'Pусский'}]  Released
# tt1107828                                                NaN  Released
# tt0116485           [{'iso_639_1': 'de', 'name': 'Deutsch'}]  Released
#
#                                                      tagline  \
# imdb_id
# tt1321865                     The man who hijacked the world
# tt0056937  The motion picture the world has been waiting ...
# tt0049833                                                NaN
# tt0080855  The only thing greater than their passion for ...
# tt0279111                The nations heart was touched by...
# ...                                                      ...
# tt0278675                                                NaN
# tt2456720                                                NaN
# tt1620549                                                NaN
# tt1107828                                                NaN
# tt0116485                                                NaN
#
#                                           title  \
# imdb_id
# tt1321865                                Carlos
# tt0056937                             Cleopatra
# tt0049833                  The Ten Commandments
# tt0080855                         Heaven's Gate
# tt0279111                     Gods and Generals
# ...                                         ...
# tt0278675                            Revelation
# tt2456720             Tutto tutto niente niente
# tt1620549  Hooked on the Game 2. The Next Level
# tt1107828                               Королёв
# tt0116485                         Happy Weekend
#
#                                                     Keywords  \
# imdb_id
# tt1321865  [{'id': 1419, 'name': 'gun'}, {'id': 7336, 'na...
# tt0056937  [{'id': 5049, 'name': 'ancient rome'}, {'id': ...
# tt0049833  [{'id': 1160, 'name': 'egypt'}, {'id': 2618, '...
# tt0080855  [{'id': 680, 'name': 'montana'}, {'id': 797, '...
# tt0279111  [{'id': 6091, 'name': 'war'}, {'id': 14643, 'n...
# ...                                                      ...
# tt0278675                                                NaN
# tt2456720  [{'id': 8201, 'name': 'satire'}, {'id': 33501,...
# tt1620549                                                NaN
# tt1107828                                                NaN
# tt0116485  [{'id': 572, 'name': 'sex'}, {'id': 596, 'name...
#
#                                                         cast      revenue  \
# imdb_id
# tt1321865  [{'cast_id': 4, 'character': "Ilich Ram√≠rez S...     871279.0
# tt0056937  [{'cast_id': 2, 'character': 'Cleopatra', 'cre...   71000000.0
# tt0049833  [{'cast_id': 9, 'character': 'Moses', 'credit_...  122700000.0
# tt0080855  [{'cast_id': 1, 'character': 'James Averill', ...    3484331.0
# tt0279111  [{'cast_id': 3, 'character': 'Lt. Gen. Thomas ...   12923936.0
# ...                                                      ...          ...
# tt0278675  [{'cast_id': 1, 'character': 'Jake Martel', 'c...   10000000.0
# tt2456720  [{'cast_id': 1, 'character': 'Cetto La Qualunq...    8927600.0
# tt1620549  [{'cast_id': 10, 'character': 'Vampire', 'cred...    2294357.0
# tt1107828  [{'cast_id': 3, 'character': '–°–µ—Ä–≥–µ–π –ö–...      31000.0
# tt0116485  [{'cast_id': 0, 'character': 'Joachim Krippo',...      65335.0
#
#           movie_profit                     Capitalized_title   new_profit
# imdb_id
# tt1321865    -17128721                                CARLOS  -17128721.0
# tt0056937     39885000                             CLEOPATRA   39885000.0
# tt0049833    109700000                  THE TEN COMMANDMENTS  109700000.0
# tt0080855    -40515669                         HEAVEN'S GATE  -40515669.0
# tt0279111    -43076064                     GODS AND GENERALS  -43076064.0
# ...                ...                                   ...          ...
# tt0278675     10000000                            REVELATION   10000000.0
# tt2456720      3347850             TUTTO TUTTO NIENTE NIENTE    3347850.0
# tt1620549     -1205643  HOOKED ON THE GAME 2. THE NEXT LEVEL   -1205643.0
# tt1107828     -5969000                               КОРОЛЁВ   -5969000.0
# tt0116485        65335                         HAPPY WEEKEND      65335.0
#
# [3000 rows x 22 columns]

# %%
# We can also sort by the combination of two columns
df.sort_values(['status','new_profit'], ascending=[False,True]).head()
# Out:
#                                        belongs_to_collection     budget  \
# imdb_id
# tt0145394                                                NaN     891000
# tt1860180                                                NaN          0
# tt0120254  [{'id': 144200, 'name': 'Swan Princess Series'...          0
# tt0091024                                                NaN          0
# tt2239822                                                NaN  197471676
#
#                                                       genres homepage  \
# imdb_id
# tt0145394                [{'id': 99, 'name': 'Documentary'}]      NaN
# tt1860180                     [{'id': 35, 'name': 'Comedy'}]      NaN
# tt0120254  [{'id': 14, 'name': 'Fantasy'}, {'id': 16, 'na...      NaN
# tt0091024  [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...      NaN
# tt2239822  [{'id': 12, 'name': 'Adventure'}, {'id': 878, ...      NaN
#
#           original_language                                  original_title  \
# imdb_id
# tt0145394                en                          A Place Called Chiapas
# tt1860180                en                         Billy Gardell: Halftime
# tt0120254                en  The Swan Princess: Escape from Castle Mountain
# tt0091024                en                                     Extremities
# tt2239822                en     Valerian and the City of a Thousand Planets
#
#                                                     overview  popularity  \
# imdb_id
# tt0145394  On January 1, 1994, the Zapatista National Lib...    0.179246
# tt1860180  Billy Gardell, the star of CBS' hit comedy "Mi...    0.007877
# tt0120254  The first wedding anniversary of Princess Odet...    5.121309
# tt0091024  A woman escapes from the man who is about to r...   10.273979
# tt2239822  In the 28th century, Valerian and Laureline ar...   15.262706
#
#                                         production_companies  \
# imdb_id
# tt0145394                                                NaN
# tt1860180                                                NaN
# tt0120254                                                NaN
# tt0091024  [{'name': 'Atlantic Entertainment Group', 'id'...
# tt2239822               [{'name': 'EuropaCorp', 'id': 6896}]
#
#                                         production_countries  ...  \
# imdb_id                                                       ...
# tt0145394           [{'iso_3166_1': 'CA', 'name': 'Canada'}]  ...
# tt1860180  [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# tt0120254                                                NaN  ...
# tt0091024  [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# tt2239822           [{'iso_3166_1': 'FR', 'name': 'France'}]  ...
#
#                                             spoken_languages    status  \
# imdb_id
# tt0145394  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...   Rumored
# tt1860180           [{'iso_639_1': 'en', 'name': 'English'}]   Rumored
# tt0120254  [{'iso_639_1': 'da', 'name': 'Dansk'}, {'iso_6...   Rumored
# tt0091024           [{'iso_639_1': 'en', 'name': 'English'}]   Rumored
# tt2239822  [{'iso_639_1': 'fr', 'name': 'Français'}, {'is...  Released
#
#                                                      tagline  \
# imdb_id
# tt0145394     Inside the world's first postmodern revolution
# tt1860180                                                NaN
# tt0120254  It Will Take All Her Magic to Rescue Her Friends!
# tt0091024  When fear made her a victim, she turned fear i...
# tt2239822                                                NaN
#
#                                                     title  \
# imdb_id
# tt0145394                          A Place Called Chiapas
# tt1860180                         Billy Gardell: Halftime
# tt0120254  The Swan Princess: Escape from Castle Mountain
# tt0091024                                     Extremities
# tt2239822     Valerian and the City of a Thousand Planets
#
#                                                     Keywords  \
# imdb_id
# tt0145394         [{'id': 187056, 'name': 'woman director'}]
# tt1860180                                                NaN
# tt0120254  [{'id': 3071, 'name': 'prince'}, {'id': 4456, ...
# tt0091024  [{'id': 2483, 'name': 'nudity'}, {'id': 2539, ...
# tt2239822  [{'id': 1370, 'name': 'shapeshifting'}, {'id':...
#
#                                                         cast     revenue  \
# imdb_id
# tt0145394  [{'cast_id': 1, 'character': 'Himself', 'credi...    229000.0
# tt1860180  [{'cast_id': 9, 'character': 'Himself', 'credi...        60.0
# tt0120254  [{'cast_id': 2, 'character': 'Odette (voice)',...    273644.0
# tt0091024  [{'cast_id': 1, 'character': 'Marjorie', 'cred...  13418091.0
# tt2239822                                                NaN  90024292.0
#
#           movie_profit                               Capitalized_title  \
# imdb_id
# tt0145394      -662000                          A PLACE CALLED CHIAPAS
# tt1860180           60                         BILLY GARDELL: HALFTIME
# tt0120254       273644  THE SWAN PRINCESS: ESCAPE FROM CASTLE MOUNTAIN
# tt0091024     13418091                                     EXTREMITIES
# tt2239822   -107447384     VALERIAN AND THE CITY OF A THOUSAND PLANETS
#
#             new_profit
# imdb_id
# tt0145394    -662000.0
# tt1860180         60.0
# tt0120254     273644.0
# tt0091024   13418091.0
# tt2239822 -107447384.0
#
# [5 rows x 22 columns]

# %% [markdown]
# ## <b>Let us explore some datetime operations and functions

# %% [markdown]
# Directive
#
# *  <b>%a</b>	Weekday as locale’s abbreviated name.	Sun, Mon, …, Sat (en_US)
# So, Mo, …, Sa (de_DE)
# *  <b>%A</b>	Weekday as locale’s full name.	Sunday, Monday, …, Saturday (en_US)
# Sonntag, Montag, …, Samstag (de_DE)
# *  <b>%w</b>	Weekday as a decimal number, where 0 is Sunday and 6 is Saturday.	0, 1, 2, 3, 4, 5, 6
# *  <b>%d</b>	Day of the month as a zero-padded decimal number.	01, 02, …, 31
# *  <b>%b</b>	Month as locale’s abbreviated name.	Jan, Feb, …, Dec (en_US)
# Jan, Feb, …, Dez (de_DE)
# *  <b>%B</b>	Month as locale’s full name.	January, February, …, December (en_US)
# Januar, Februar, …, Dezember (de_DE)
# *  <b>%m</b>	Month as a zero-padded decimal number.	01, 02 … 12
# *  <b>%y</b>	Year without century as a zero-padded decimal number.	01, 02, … 99
# *  <b>%Y</b>	Year with century as a decimal number.	0001, 0002, … , 9999
# *  <b>%H</b>	Hour (24-hour clock) as a zero-padded decimal number.	01, 02, … , 23
# *  <b>%I</b>	Hour (12-hour clock) as a zero-padded decimal number.	01, 02, … , 12
# *  <b>%p</b>	Locale’s equivalent of either AM or PM.	AM, PM (en_US)
# am, pm (de_DE)
# *  <b>%M</b>	Minute as a zero-padded decimal number.	01, 02, … , 59
# *  <b>%S</b>	Second as a zero-padded decimal number.	01, 02, … , 59
# *  <b>%f</b>	Microsecond as a decimal number, zero-padded on the left.	000000, 000001, …, 999999

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3000 entries, tt2637294 to tt1600195
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  604 non-null    object
#  1   budget                 3000 non-null   int64
#  2   genres                 2993 non-null   object
#  3   homepage               946 non-null    object
#  4   original_language      3000 non-null   object
#  5   original_title         3000 non-null   object
#  6   overview               2992 non-null   object
#  7   popularity             3000 non-null   float64
#  8   production_companies   2844 non-null   object
#  9   production_countries   2945 non-null   object
#  10  release_date           3000 non-null   object
#  11  runtime                2998 non-null   float64
#  12  spoken_languages       2980 non-null   object
#  13  status                 3000 non-null   object
#  14  tagline                2403 non-null   object
#  15  title                  3000 non-null   object
#  16  Keywords               2724 non-null   object
#  17  cast                   2987 non-null   object
#  18  revenue                2998 non-null   float64
#  19  movie_profit           3000 non-null   int64
#  20  Capitalized_title      3000 non-null   object
#  21  new_profit             2998 non-null   float64
# dtypes: float64(4), int64(2), object(16)
# memory usage: 603.6+ KB

# %%
df['release_date'][0:5]
# Out:
# imdb_id
# tt2637294     2/20/15
# tt0368933      8/6/04
# tt2582802    10/10/14
# tt1821480      3/9/12
# tt1380152      2/5/09
# Name: release_date, dtype: object

# %%
# Importing datetime modules
from datetime import datetime
from datetime import date

# %% [markdown]
# ### <code>strptime</code> means string parser, this will convert a string format to datetime.
#
# ### <code>strftime</code> means string formatter, this will format a datetime object to string format.

# %%
df['release_date'][0:5]
# Out:
# imdb_id
# tt2637294     2/20/15
# tt0368933      8/6/04
# tt2582802    10/10/14
# tt1821480      3/9/12
# tt1380152      2/5/09
# Name: release_date, dtype: object

# %%
df['new_release_date']=df['release_date'].apply(lambda x : datetime.strptime(x,'%m/%d/%y'))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3000 entries, tt2637294 to tt1600195
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  604 non-null    object
#  1   budget                 3000 non-null   int64
#  2   genres                 2993 non-null   object
#  3   homepage               946 non-null    object
#  4   original_language      3000 non-null   object
#  5   original_title         3000 non-null   object
#  6   overview               2992 non-null   object
#  7   popularity             3000 non-null   float64
#  8   production_companies   2844 non-null   object
#  9   production_countries   2945 non-null   object
#  10  release_date           3000 non-null   object
#  11  runtime                2998 non-null   float64
#  12  spoken_languages       2980 non-null   object
#  13  status                 3000 non-null   object
#  14  tagline                2403 non-null   object
#  15  title                  3000 non-null   object
#  16  Keywords               2724 non-null   object
#  17  cast                   2987 non-null   object
#  18  revenue                2998 non-null   float64
#  19  movie_profit           3000 non-null   int64
#  20  Capitalized_title      3000 non-null   object
#  21  new_profit             2998 non-null   float64
#  22  new_release_date       3000 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(4), int64(2), object(16)
# memory usage: 627.0+ KB

# %%
df.head()
# Out:
#                                        belongs_to_collection    budget  \
# imdb_id
# tt2637294  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# tt0368933  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# tt2582802                                                NaN   3300000
# tt1821480                                                NaN   1200000
# tt1380152                                                NaN         0
#
#                                                       genres  \
# imdb_id
# tt2637294                     [{'id': 35, 'name': 'Comedy'}]
# tt0368933  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# tt2582802                      [{'id': 18, 'name': 'Drama'}]
# tt1821480  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# tt1380152  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                                     homepage original_language  \
# imdb_id
# tt2637294                                NaN                en
# tt0368933                                NaN                en
# tt2582802  http://sonyclassics.com/whiplash/                en
# tt1821480         http://kahaanithefilm.com/                hi
# tt1380152                                NaN                ko
#
#                                      original_title  \
# imdb_id
# tt2637294                    Hot Tub Time Machine 2
# tt0368933  The Princess Diaries 2: Royal Engagement
# tt2582802                                  Whiplash
# tt1821480                                   Kahaani
# tt1380152                                      마린보이
#
#                                                     overview  popularity  \
# imdb_id
# tt2637294  When Lou, who has become the "father of the In...    6.575393
# tt0368933  Mia Thermopolis is now a college graduate and ...    8.248895
# tt2582802  Under the direction of a ruthless instructor, ...   64.299990
# tt1821480  Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936
# tt1380152  Marine Boy is the story of a former national s...    1.148070
#
#                                         production_companies  \
# imdb_id
# tt2637294  [{'name': 'Paramount Pictures', 'id': 4}, {'na...
# tt0368933        [{'name': 'Walt Disney Pictures', 'id': 2}]
# tt2582802  [{'name': 'Bold Films', 'id': 2266}, {'name': ...
# tt1821480                                                NaN
# tt1380152                                                NaN
#
#                                         production_countries  ...    status  \
# imdb_id                                                       ...
# tt2637294  [{'iso_3166_1': 'US', 'name': 'United States o...  ...  Released
# tt0368933  [{'iso_3166_1': 'US', 'name': 'United States o...  ...  Released
# tt2582802  [{'iso_3166_1': 'US', 'name': 'United States o...  ...  Released
# tt1821480            [{'iso_3166_1': 'IN', 'name': 'India'}]  ...  Released
# tt1380152      [{'iso_3166_1': 'KR', 'name': 'South Korea'}]  ...  Released
#
#                                                      tagline  \
# imdb_id
# tt2637294  The Laws of Space and Time are About to be Vio...
# tt0368933  It can take a lifetime to find true love; she'...
# tt2582802    The road to greatness can take you to the edge.
# tt1821480                                                NaN
# tt1380152                                                NaN
#
#                                               title  \
# imdb_id
# tt2637294                    Hot Tub Time Machine 2
# tt0368933  The Princess Diaries 2: Royal Engagement
# tt2582802                                  Whiplash
# tt1821480                                   Kahaani
# tt1380152                                Marine Boy
#
#                                                     Keywords  \
# imdb_id
# tt2637294  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# tt0368933  [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# tt2582802  [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# tt1821480  [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# tt1380152                                                NaN
#
#                                                         cast     revenue  \
# imdb_id
# tt2637294  [{'cast_id': 4, 'character': 'Lou', 'credit_id...         NaN
# tt0368933  [{'cast_id': 1, 'character': 'Mia Thermopolis'...         NaN
# tt2582802  [{'cast_id': 5, 'character': 'Andrew Neimann',...  13092000.0
# tt1821480  [{'cast_id': 1, 'character': 'Vidya Bagchi', '...  16000000.0
# tt1380152  [{'cast_id': 3, 'character': 'Chun-soo', 'cred...   3923970.0
#
#           movie_profit                         Capitalized_title  new_profit  \
# imdb_id
# tt2637294     -1685349                    HOT TUB TIME MACHINE 2         NaN
# tt0368933     55149435  THE PRINCESS DIARIES 2: ROYAL ENGAGEMENT         NaN
# tt2582802      9792000                                  WHIPLASH   9792000.0
# tt1821480     14800000                                   KAHAANI  14800000.0
# tt1380152      3923970                                MARINE BOY   3923970.0
#
#            new_release_date
# imdb_id
# tt2637294        2015-02-20
# tt0368933        2004-08-06
# tt2582802        2014-10-10
# tt1821480        2012-03-09
# tt1380152        2009-02-05
#
# [5 rows x 23 columns]

# %%
df['new_release_date'][0]
# Out:
# Timestamp('2015-02-20 00:00:00')

# %%
# Month year date
print(df['new_release_date'][0].month)
print(df['new_release_date'][0].year)
print(df['new_release_date'][0].day)
print(df['new_release_date'][0].hour)
print(df['new_release_date'][0].minute)
# Out:
# 2
# 2015
# 20
# 0
# 0

# %%
print(date.today())
print(datetime.now())
# Out:
# 2024-03-09
# 2024-03-09 12:52:20.344294

# %%
# Some operations we can do on datetime 
from datetime import timedelta
print(date.today())
print(date.today() - timedelta(days=1))
print(datetime.now() + timedelta(hours=5.5))
print(datetime.now() + timedelta(seconds=60))
# Out:
# 2024-03-09
# 2024-03-08
# 2024-03-09 18:22:20.552396
# 2024-03-09 12:53:20.552396

# %%
print(df['new_release_date'][0])
print(df['new_release_date'][5])
# Out:
# 2015-02-20 00:00:00
# 1987-08-06 00:00:00

# %%
# Difference in two datetime
time_delta=df['new_release_date'][0]-df['new_release_date'][5]
time_delta
# Out:
# Timedelta('10060 days 00:00:00')

# %%
type(time_delta)
# Out:
# pandas._libs.tslibs.timedeltas.Timedelta

# %%
time_delta.total_seconds()
# Out:
# 869184000.0

# %%
t1 = pd.to_datetime('1/1/2015 01:00')
t2 = pd.to_datetime('1/1/2015 03:30')

print(pd.Timedelta(t2 - t1).seconds / 3600.0)
# Out:
# 2.5

# %% [markdown]
# ### Let's explore the unique and missing values

# %% [markdown]
# * <code>unique()</code>
# * <code>nunique()</code>
# * <code>value_counts()</code>
# * <code>isnull()</code>
# * <code>fillna()</code>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3000 entries, tt2637294 to tt1600195
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  604 non-null    object
#  1   budget                 3000 non-null   int64
#  2   genres                 2993 non-null   object
#  3   homepage               946 non-null    object
#  4   original_language      3000 non-null   object
#  5   original_title         3000 non-null   object
#  6   overview               2992 non-null   object
#  7   popularity             3000 non-null   float64
#  8   production_companies   2844 non-null   object
#  9   production_countries   2945 non-null   object
#  10  release_date           3000 non-null   object
#  11  runtime                2998 non-null   float64
#  12  spoken_languages       2980 non-null   object
#  13  status                 3000 non-null   object
#  14  tagline                2403 non-null   object
#  15  title                  3000 non-null   object
#  16  Keywords               2724 non-null   object
#  17  cast                   2987 non-null   object
#  18  revenue                2998 non-null   float64
#  19  movie_profit           3000 non-null   int64
#  20  Capitalized_title      3000 non-null   object
#  21  new_profit             2998 non-null   float64
#  22  new_release_date       3000 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(4), int64(2), object(16)
# memory usage: 627.0+ KB

# %%
# Find the list of unique values in a column
list(df['status'].unique())
# Out:
# ['Released', 'Rumored']

# %%
list(df['original_language'].unique())
# Out:
# ['en',
#  'hi',
#  'ko',
#  'sr',
#  'fr',
#  'it',
#  'nl',
#  'zh',
#  'es',
#  'cs',
#  'ta',
#  'cn',
#  'ru',
#  'tr',
#  'ja',
#  'fa',
#  'sv',
#  'de',
#  'te',
#  'pt',
#  'mr',
#  'da',
#  'fi',
#  'el',
#  'ur',
#  'he',
#  'no',
#  'ar',
#  'nb',
#  'ro',
#  'vi',
#  'pl',
#  'hu',
#  'ml',
#  'bn',
#  'id']

# %%
# Counts the number of unique values in a column
df.original_language.nunique()
# Out:
# 36

# %%
# Give the counts of each category of a variable
df['original_language'].value_counts()
# Out:
# en    2575
# fr      78
# ru      47
# es      43
# hi      42
# ja      37
# it      24
# cn      20
# ko      20
# zh      19
# de      18
# ta      16
# sv       8
# nl       6
# pt       6
# fa       5
# da       5
# ro       4
# hu       3
# tr       3
# no       2
# ml       2
# pl       2
# te       2
# fi       2
# ur       1
# he       1
# el       1
# ar       1
# nb       1
# vi       1
# mr       1
# cs       1
# sr       1
# bn       1
# id       1
# Name: original_language, dtype: int64

# %%
# Does not make much sense to use value_counts for a numeric variable
df.runtime.value_counts()
# Out:
# 90.0     100
# 100.0     99
# 105.0     91
# 95.0      89
# 98.0      85
#         ...
# 220.0      1
# 60.0       1
# 53.0       1
# 185.0      1
# 182.0      1
# Name: runtime, Length: 139, dtype: int64

# %%
# Returns a series of booleans if a column value contains nulls
df['homepage'].isnull()
# Out:
# imdb_id
# tt2637294     True
# tt0368933     True
# tt2582802    False
# tt1821480    False
# tt1380152     True
#              ...
# tt0109403     True
# tt2364975     True
# tt0116908     True
# tt0343135    False
# tt1600195    False
# Name: homepage, Length: 3000, dtype: bool

# %%
df[~df['homepage'].isnull()]
# Out:
#                                        belongs_to_collection    budget  \
# imdb_id
# tt2582802                                                NaN   3300000
# tt1821480                                                NaN   1200000
# tt0431021                                                NaN  14000000
# tt0169547                                                NaN  15000000
# tt1129437                                                NaN    500000
# ...                                                      ...       ...
# tt0257076  [{'id': 221111, 'name': 'S.W.A.T. Collection',...  80000000
# tt0349467                                                NaN  37665000
# tt0362227                                                NaN  60000000
# tt0343135                                                NaN  42000000
# tt1600195                                                NaN  35000000
#
#                                                       genres  \
# imdb_id
# tt2582802                      [{'id': 18, 'name': 'Drama'}]
# tt1821480  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# tt0431021  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
# tt0169547                      [{'id': 18, 'name': 'Drama'}]
# tt1129437  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# ...                                                      ...
# tt0257076  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# tt0349467  [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...
# tt0362227  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# tt0343135  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# tt1600195  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
#
#                                                     homepage  \
# imdb_id
# tt2582802                  http://sonyclassics.com/whiplash/
# tt1821480                         http://kahaanithefilm.com/
# tt0431021                 http://www.thepossessionmovie.com/
# tt0169547                      http://www.dreamworks.com/ab/
# tt1129437              http://skinningmovie.com/synopsis.htm
# ...                                                      ...
# tt0257076        http://www.sonypictures.com/homevideo/swat/
# tt0349467  http://www.sonypictures.com/homevideo/freedoml...
# tt0362227               http://www.theterminal-themovie.com/
# tt0343135                     http://www.alongcamepolly.com/
# tt1600195                   http://www.abductionthefilm.com/
#
#           original_language    original_title  \
# imdb_id
# tt2582802                en          Whiplash
# tt1821480                hi           Kahaani
# tt0431021                en    The Possession
# tt0169547                en   American Beauty
# tt1129437                sr           Šišanje
# ...                     ...               ...
# tt0257076                en          S.W.A.T.
# tt0349467                en       Freedomland
# tt0362227                en      The Terminal
# tt0343135                en  Along Came Polly
# tt1600195                en         Abduction
#
#                                                     overview  popularity  \
# imdb_id
# tt2582802  Under the direction of a ruthless instructor, ...   64.299990
# tt1821480  Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936
# tt0431021  A young girl buys an antique box at a yard sal...    7.286477
# tt0169547  Lester Burnham, a depressed suburban father in...   20.726578
# tt1129437  Novica is a mathematics champion in a Belgrade...    1.018477
# ...                                                      ...         ...
# tt0257076  Hondo Harrelson recruits Jim Street to join an...   13.334952
# tt0349467  A black police detective must solve a strange ...    5.388535
# tt0362227  Viktor Navorski is a man without a country; hi...   14.092373
# tt0343135  Reuben Feffer is a guy who's spent his entire ...   15.725542
# tt1600195  A young man sets out to uncover the truth abou...   10.512109
#
#                                         production_companies  \
# imdb_id
# tt2582802  [{'name': 'Bold Films', 'id': 2266}, {'name': ...
# tt1821480                                                NaN
# tt0431021  [{'name': 'Ghost House Pictures', 'id': 768}, ...
# tt0169547  [{'name': 'DreamWorks SKG', 'id': 27}, {'name'...
# tt1129437              [{'name': 'Hypnopolis', 'id': 51316}]
# ...                                                      ...
# tt0257076  [{'name': 'Original Film', 'id': 333}, {'name'...
# tt0349467  [{'name': 'Scott Rudin Productions', 'id': 258...
# tt0362227  [{'name': 'DreamWorks SKG', 'id': 27}, {'name'...
# tt0343135  [{'name': 'Jersey Films', 'id': 216}, {'name':...
# tt1600195  [{'name': 'Lions Gate Films', 'id': 35}, {'nam...
#
#                                         production_countries  ...    status  \
# imdb_id                                                       ...
# tt2582802  [{'iso_3166_1': 'US', 'name': 'United States o...  ...  Released
# tt1821480            [{'iso_3166_1': 'IN', 'name': 'India'}]  ...  Released
# tt0431021  [{'iso_3166_1': 'US', 'name': 'United States o...  ...  Released
# tt0169547  [{'iso_3166_1': 'US', 'name': 'United States o...  ...  Released
# tt1129437           [{'iso_3166_1': 'RS', 'name': 'Serbia'}]  ...  Released
# ...                                                      ...  ...       ...
# tt0257076  [{'iso_3166_1': 'US', 'name': 'United States o...  ...  Released
# tt0349467  [{'iso_3166_1': 'US', 'name': 'United States o...  ...  Released
# tt0362227  [{'iso_3166_1': 'US', 'name': 'United States o...  ...  Released
# tt0343135  [{'iso_3166_1': 'US', 'name': 'United States o...  ...  Released
# tt1600195  [{'iso_3166_1': 'US', 'name': 'United States o...  ...  Released
#
#                                                      tagline  \
# imdb_id
# tt2582802    The road to greatness can take you to the edge.
# tt1821480                                                NaN
# tt0431021               Fear The Demon That Doesn't Fear God
# tt0169547                                       Look closer.
# tt1129437  Life is sometimes rude game: one mistake can b...
# ...                                                      ...
# tt0257076              You're either S.W.A.T. or you're not.
# tt0349467    The Truth Is Hiding Where No One Dares To Look.
# tt0362227                                   Life is waiting.
# tt0343135  For the most cautious man on Earth, life is ab...
# tt1600195          They stole his life. He's taking it back.
#
#                       title  \
# imdb_id
# tt2582802          Whiplash
# tt1821480           Kahaani
# tt0431021    The Possession
# tt0169547   American Beauty
# tt1129437          Skinning
# ...                     ...
# tt0257076          S.W.A.T.
# tt0349467       Freedomland
# tt0362227      The Terminal
# tt0343135  Along Came Polly
# tt1600195         Abduction
#
#                                                     Keywords  \
# imdb_id
# tt2582802  [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# tt1821480  [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# tt0431021                                                NaN
# tt0169547  [{'id': 255, 'name': 'male nudity'}, {'id': 29...
# tt1129437  [{'id': 379, 'name': 'skinhead'}, {'id': 7492,...
# ...                                                      ...
# tt0257076  [{'id': 2434, 'name': 'liberation'}, {'id': 35...
# tt0349467  [{'id': 577, 'name': 'black people'}, {'id': 5...
# tt0362227  [{'id': 242, 'name': 'new york'}, {'id': 822, ...
# tt0343135  [{'id': 966, 'name': 'beach'}, {'id': 2676, 'n...
# tt1600195  [{'id': 591, 'name': 'cia'}, {'id': 822, 'name...
#
#                                                         cast      revenue  \
# imdb_id
# tt2582802  [{'cast_id': 5, 'character': 'Andrew Neimann',...   13092000.0
# tt1821480  [{'cast_id': 1, 'character': 'Vidya Bagchi', '...   16000000.0
# tt0431021  [{'cast_id': 23, 'character': 'Clyde', 'credit...   85446075.0
# tt0169547  [{'cast_id': 6, 'character': 'Lester Burnham',...  356296601.0
# tt1129437  [{'cast_id': 1001, 'character': 'Novica', 'cre...        198.0
# ...                                                      ...          ...
# tt0257076  [{'cast_id': 25, 'character': "Sgt. Dan 'Hondo...  116643346.0
# tt0349467  [{'cast_id': 13, 'character': 'Lorenzo Council...   14655628.0
# tt0362227  [{'cast_id': 4, 'character': 'Viktor Navorski'...  219417255.0
# tt0343135  [{'cast_id': 8, 'character': 'Reuben Feffer', ...  171963386.0
# tt1600195  [{'cast_id': 2, 'character': 'Nathan Harper', ...   82087155.0
#
#           movie_profit Capitalized_title   new_profit  new_release_date
# imdb_id
# tt2582802      9792000          WHIPLASH    9792000.0        2014-10-10
# tt1821480     14800000           KAHAANI   14800000.0        2012-03-09
# tt0431021     71446075    THE POSSESSION   71446075.0        2012-08-30
# tt0169547    341296601   AMERICAN BEAUTY  341296601.0        1999-09-15
# tt1129437      -499802          SKINNING    -499802.0        2010-10-06
# ...                ...               ...          ...               ...
# tt0257076     36643346          S.W.A.T.   36643346.0        2003-08-08
# tt0349467    -23009372       FREEDOMLAND  -23009372.0        2006-02-17
# tt0362227    159417255      THE TERMINAL  159417255.0        2004-06-17
# tt0343135    129963386  ALONG CAME POLLY  129963386.0        2004-01-16
# tt1600195     47087155         ABDUCTION   47087155.0        2011-09-22
#
# [946 rows x 23 columns]

# %%
# Lets fill the missing values with the value -999
df['homepage'].fillna('Not Present',inplace = True)

# %%
df.head()
# Out:
#                                        belongs_to_collection    budget  \
# imdb_id
# tt2637294  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# tt0368933  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# tt2582802                                                NaN   3300000
# tt1821480                                                NaN   1200000
# tt1380152                                                NaN         0
#
#                                                       genres  \
# imdb_id
# tt2637294                     [{'id': 35, 'name': 'Comedy'}]
# tt0368933  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# tt2582802                      [{'id': 18, 'name': 'Drama'}]
# tt1821480  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# tt1380152  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                                     homepage original_language  \
# imdb_id
# tt2637294                        Not Present                en
# tt0368933                        Not Present                en
# tt2582802  http://sonyclassics.com/whiplash/                en
# tt1821480         http://kahaanithefilm.com/                hi
# tt1380152                        Not Present                ko
#
#                                      original_title  \
# imdb_id
# tt2637294                    Hot Tub Time Machine 2
# tt0368933  The Princess Diaries 2: Royal Engagement
# tt2582802                                  Whiplash
# tt1821480                                   Kahaani
# tt1380152                                      마린보이
#
#                                                     overview  popularity  \
# imdb_id
# tt2637294  When Lou, who has become the "father of the In...    6.575393
# tt0368933  Mia Thermopolis is now a college graduate and ...    8.248895
# tt2582802  Under the direction of a ruthless instructor, ...   64.299990
# tt1821480  Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936
# tt1380152  Marine Boy is the story of a former national s...    1.148070
#
#                                         production_companies  \
# imdb_id
# tt2637294  [{'name': 'Paramount Pictures', 'id': 4}, {'na...
# tt0368933        [{'name': 'Walt Disney Pictures', 'id': 2}]
# tt2582802  [{'name': 'Bold Films', 'id': 2266}, {'name': ...
# tt1821480                                                NaN
# tt1380152                                                NaN
#
#                                         production_countries  ...    status  \
# imdb_id                                                       ...
# tt2637294  [{'iso_3166_1': 'US', 'name': 'United States o...  ...  Released
# tt0368933  [{'iso_3166_1': 'US', 'name': 'United States o...  ...  Released
# tt2582802  [{'iso_3166_1': 'US', 'name': 'United States o...  ...  Released
# tt1821480            [{'iso_3166_1': 'IN', 'name': 'India'}]  ...  Released
# tt1380152      [{'iso_3166_1': 'KR', 'name': 'South Korea'}]  ...  Released
#
#                                                      tagline  \
# imdb_id
# tt2637294  The Laws of Space and Time are About to be Vio...
# tt0368933  It can take a lifetime to find true love; she'...
# tt2582802    The road to greatness can take you to the edge.
# tt1821480                                                NaN
# tt1380152                                                NaN
#
#                                               title  \
# imdb_id
# tt2637294                    Hot Tub Time Machine 2
# tt0368933  The Princess Diaries 2: Royal Engagement
# tt2582802                                  Whiplash
# tt1821480                                   Kahaani
# tt1380152                                Marine Boy
#
#                                                     Keywords  \
# imdb_id
# tt2637294  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# tt0368933  [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# tt2582802  [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# tt1821480  [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# tt1380152                                                NaN
#
#                                                         cast     revenue  \
# imdb_id
# tt2637294  [{'cast_id': 4, 'character': 'Lou', 'credit_id...         NaN
# tt0368933  [{'cast_id': 1, 'character': 'Mia Thermopolis'...         NaN
# tt2582802  [{'cast_id': 5, 'character': 'Andrew Neimann',...  13092000.0
# tt1821480  [{'cast_id': 1, 'character': 'Vidya Bagchi', '...  16000000.0
# tt1380152  [{'cast_id': 3, 'character': 'Chun-soo', 'cred...   3923970.0
#
#           movie_profit                         Capitalized_title  new_profit  \
# imdb_id
# tt2637294     -1685349                    HOT TUB TIME MACHINE 2         NaN
# tt0368933     55149435  THE PRINCESS DIARIES 2: ROYAL ENGAGEMENT         NaN
# tt2582802      9792000                                  WHIPLASH   9792000.0
# tt1821480     14800000                                   KAHAANI  14800000.0
# tt1380152      3923970                                MARINE BOY   3923970.0
#
#            new_release_date
# imdb_id
# tt2637294        2015-02-20
# tt0368933        2004-08-06
# tt2582802        2014-10-10
# tt1821480        2012-03-09
# tt1380152        2009-02-05
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Merge & Groupby Operations in Pandas

# %% [markdown]
# ### **We can merge dataframes using the following methods**
#
# * <code> pd.concat( [df] , axis) </code>
#
# * <code> pd.merge( df1, df2 ,on,how,suffixes) </code>
#
#
#
#
# ### More detailed documentation here : https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html

# %%
imdb_df=pd.read_csv(r'C:\Users\malik\Downloads\imdb_data1.csv')
imdb_df.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# 2  http://sonyclassics.com/whiplash/  tt2582802                en
# 3         http://kahaanithefilm.com/  tt1821480                hi
# 4                                NaN  tt1380152                ko
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                      마린보이
#
#                                             overview  popularity  ...  \
# 0  When Lou, who has become the "father of the In...    6.575393  ...
# 1  Mia Thermopolis is now a college graduate and ...    8.248895  ...
# 2  Under the direction of a ruthless instructor, ...   64.299990  ...
# 3  Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936  ...
# 4  Marine Boy is the story of a former national s...    1.148070  ...
#
#   release_date runtime                                   spoken_languages  \
# 0      2/20/15    93.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1       8/6/04   113.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2     10/10/14   105.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3       3/9/12   122.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 4       2/5/09   118.0           [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]
#
#      status                                            tagline  \
# 0  Released  The Laws of Space and Time are About to be Vio...
# 1  Released  It can take a lifetime to find true love; she'...
# 2  Released    The road to greatness can take you to the edge.
# 3  Released                                                NaN
# 4  Released                                                NaN
#
#                                       title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1  [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2  [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 3  [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 4                                                NaN
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1  [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2  [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3  [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4  [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
#
#                                                 crew   revenue
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651
# 1  [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435
# 2  [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000
# 3  [{'credit_id': '52fe48779251416c9108d6eb', 'de...  16000000
# 4  [{'credit_id': '52fe464b9251416c75073b43', 'de...   3923970
#
# [5 rows x 23 columns]

# %%
imdb_df.drop('id',axis=1,inplace=True)

# %% [markdown]
# ### Let us go ahead and create three subsets of our original dataset

# %%
# Create three dataframes
imdb1 = imdb_df[imdb_df['runtime'] >= 150]
imdb2 = imdb_df[ (imdb_df['runtime'] < 150) & (imdb_df['runtime'] > 100 )]
imdb3 = imdb_df[imdb_df['runtime'] <= 100]

# %%
imdb1.head()
# Out:
#     belongs_to_collection    budget  \
# 47                    NaN  44000000
# 51                    NaN  12000000
# 76                    NaN    500000
# 97                    NaN         0
# 107                   NaN  72000000
#
#                                                 genres  \
# 47   [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 51   [{'id': 12, 'name': 'Adventure'}, {'id': 35, '...
# 76   [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 97   [{'id': 14, 'name': 'Fantasy'}, {'id': 18, 'na...
# 107  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
#
#                         homepage    imdb_id original_language  \
# 47   http://thehatefuleight.com/  tt3460252                en
# 51                           NaN  tt0059243                en
# 76                           NaN  tt0242572                ta
# 97                           NaN  tt1772980                ru
# 107                          NaN  tt0112573                en
#
#                 original_title  \
# 47           The Hateful Eight
# 51              The Great Race
# 76   Kandukondain Kandukondain
# 97                      Mishen
# 107                 Braveheart
#
#                                               overview  popularity  \
# 47   Bounty hunters seek shelter from a raging bliz...   20.328822
# 51   Professional daredevil and white-suited hero, ...    4.473327
# 76   Two young women with differing views on love f...    0.660663
# 97   In the year 2020, a group of wealthy Moscovite...    1.042112
# 107  Enraged at the slaughter of Murron, his new br...   20.755149
#
#                           poster_path  ... release_date runtime  \
# 47   /fqe8JxDNO8B8QfOGTdjh6sPCdSC.jpg  ...     12/25/15   167.0
# 51   /nc6FRAVC4a8o4podiFy2P5qI9ul.jpg  ...       7/1/65   160.0
# 76   /AnhaX3iivU7aLc6fLuAuHXTsbgO.jpg  ...       5/5/00   157.0
# 97   /uMzkG73Y5qL9tiRrXnGlndOqhbJ.jpg  ...      6/26/11   158.0
# 107  /2qAgGeYdLjelOEqjW9FYvPHpplC.jpg  ...      5/24/95   177.0
#
#                                       spoken_languages    status  \
# 47   [{'iso_639_1': 'es', 'name': 'Español'}, {'iso...  Released
# 51   [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 76   [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 97   [{'iso_639_1': 'de', 'name': 'Deutsch'}, {'iso...  Released
# 107  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
#
#                                                tagline  \
# 47    No one comes up here without a damn good reason.
# 51   The movie with 20,000-mile or one-million-laug...
# 76                                                 NaN
# 97                                                 NaN
# 107         Every man dies. Not every man truly lives.
#
#                          title  \
# 47           The Hateful Eight
# 51              The Great Race
# 76   Kandukondain Kandukondain
# 97                      Target
# 107                 Braveheart
#
#                                               Keywords  \
# 47   [{'id': 801, 'name': 'bounty hunter'}, {'id': ...
# 51   [{'id': 9253, 'name': 'slapstick'}, {'id': 159...
# 76                                                 NaN
# 97                                                 NaN
# 107  [{'id': 30, 'name': 'individual'}, {'id': 388,...
#
#                                                   cast  \
# 47   [{'cast_id': 22, 'character': 'Major Marquis W...
# 51   [{'cast_id': 1, 'character': 'Prof. Fate', 'cr...
# 76   [{'cast_id': 1, 'character': 'Manohar', 'credi...
# 97   [{'cast_id': 1001, 'character': 'Victor', 'cre...
# 107  [{'cast_id': 5, 'character': 'William Wallace'...
#
#                                                   crew    revenue
# 47   [{'credit_id': '538aa95ec3a368714e0005b3', 'de...  155760117
# 51   [{'credit_id': '52fe445e9251416c75032581', 'de...   25333333
# 76   [{'credit_id': '52fe47c7c3a368484e0d8f41', 'de...     500000
# 97   [{'credit_id': '58cdbad4c3a36850e9011085', 'de...      73000
# 107  [{'credit_id': '52fe4225c3a36847f80079c1', 'de...  210000000
#
# [5 rows x 22 columns]

# %%
imdb2.head()
# Out:
#                                 belongs_to_collection    budget  \
# 1   [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2                                                 NaN   3300000
# 3                                                 NaN   1200000
# 4                                                 NaN         0
# 10  [{'id': 1575, 'name': 'Rocky Collection', 'pos...   1000000
#
#                                                genres  \
# 1   [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                       [{'id': 18, 'name': 'Drama'}]
# 3   [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4   [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 10                      [{'id': 18, 'name': 'Drama'}]
#
#                              homepage    imdb_id original_language  \
# 1                                 NaN  tt0368933                en
# 2   http://sonyclassics.com/whiplash/  tt2582802                en
# 3          http://kahaanithefilm.com/  tt1821480                hi
# 4                                 NaN  tt1380152                ko
# 10                                NaN  tt0075148                en
#
#                               original_title  \
# 1   The Princess Diaries 2: Royal Engagement
# 2                                   Whiplash
# 3                                    Kahaani
# 4                                       마린보이
# 10                                     Rocky
#
#                                              overview  popularity  \
# 1   Mia Thermopolis is now a college graduate and ...    8.248895
# 2   Under the direction of a ruthless instructor, ...   64.299990
# 3   Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936
# 4   Marine Boy is the story of a former national s...    1.148070
# 10  When world heavyweight boxing champion, Apollo...   14.774066
#
#                          poster_path  ... release_date runtime  \
# 1   /w9Z7A0GHEhIp7etpj0vyKOeU1Wx.jpg  ...       8/6/04   113.0
# 2   /lIv1QinFqz4dlp5U4lQ6HaiskOZ.jpg  ...     10/10/14   105.0
# 3   /aTXRaPrWSinhcmCrcfJK17urp3F.jpg  ...       3/9/12   122.0
# 4   /m22s7zvkVFDU9ir56PiiqIEWFdT.jpg  ...       2/5/09   118.0
# 10  /i5xiwdSsrecBvO7mIfAJixeEDSg.jpg  ...     11/21/76   119.0
#
#                                      spoken_languages    status  \
# 1            [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2            [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3   [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 4            [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]  Released
# 10           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                               tagline  \
# 1   It can take a lifetime to find true love; she'...
# 2     The road to greatness can take you to the edge.
# 3                                                 NaN
# 4                                                 NaN
# 10          His whole life was a million-to-one shot.
#
#                                        title  \
# 1   The Princess Diaries 2: Royal Engagement
# 2                                   Whiplash
# 3                                    Kahaani
# 4                                 Marine Boy
# 10                                     Rocky
#
#                                              Keywords  \
# 1   [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2   [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 3   [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 4                                                 NaN
# 10  [{'id': 240, 'name': 'underdog'}, {'id': 276, ...
#
#                                                  cast  \
# 1   [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2   [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3   [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4   [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
# 10  [{'cast_id': 16, 'character': 'Rocky Balboa', ...
#
#                                                  crew    revenue
# 1   [{'credit_id': '52fe43fe9251416c7502563d', 'de...   95149435
# 2   [{'credit_id': '54d5356ec3a3683ba0000039', 'de...   13092000
# 3   [{'credit_id': '52fe48779251416c9108d6eb', 'de...   16000000
# 4   [{'credit_id': '52fe464b9251416c75073b43', 'de...    3923970
# 10  [{'credit_id': '579948e9c3a36874e9007b0b', 'de...  117235147
#
# [5 rows x 22 columns]

# %%
imdb3.head()
# Out:
#                                belongs_to_collection    budget  \
# 0  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 5                                                NaN   8000000
# 6                                                NaN  14000000
# 7                                                NaN         0
# 8  [{'id': 256377, 'name': 'The Muppet Collection...         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 5  [{'id': 16, 'name': 'Animation'}, {'id': 12, '...
# 6  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
# 7                [{'id': 99, 'name': 'Documentary'}]
# 8  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
#
#                              homepage    imdb_id original_language  \
# 0                                 NaN  tt2637294                en
# 5                                 NaN  tt0093743                en
# 6  http://www.thepossessionmovie.com/  tt0431021                en
# 7                                 NaN  tt0391024                en
# 8                                 NaN  tt0117110                en
#
#                            original_title  \
# 0                  Hot Tub Time Machine 2
# 5  Pinocchio and the Emperor of the Night
# 6                          The Possession
# 7                            Control Room
# 8                  Muppet Treasure Island
#
#                                             overview  popularity  \
# 0  When Lou, who has become the "father of the In...    6.575393
# 5  Pinocchio and his friends, a glow worm and a m...    0.743274
# 6  A young girl buys an antique box at a yard sal...    7.286477
# 7  A chronicle which provides a rare window into ...    1.949044
# 8  After telling the story of Flint's last journe...    6.902423
#
#                         poster_path  ... release_date runtime  \
# 0  /tQtWuwvMf0hCc2QR2tkolwl7c3c.jpg  ...      2/20/15    93.0
# 5  /6IDqA1D2NBIVhzEEaMMRL28iBrq.jpg  ...       8/6/87    83.0
# 6  /4QjzFuaZmB4btGnLwAgdp23BzIU.jpg  ...      8/30/12    92.0
# 7  /83BV8fGy5p9i8RwE9oj76tZ1Ikp.jpg  ...      1/15/04    84.0
# 8  /5A8gKzOrF9Z7tSUX6xd5dEx4NXf.jpg  ...      2/16/96   100.0
#
#                                     spoken_languages    status  \
# 0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 5           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 6           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 7  [{'iso_639_1': 'ar', 'name': 'العربية'}, {'iso...  Released
# 8           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline  \
# 0  The Laws of Space and Time are About to be Vio...
# 5                                                NaN
# 6               Fear The Demon That Doesn't Fear God
# 7              Different channels. Different truths.
# 8                        Set sail for Muppet mayhem!
#
#                                     title  \
# 0                  Hot Tub Time Machine 2
# 5  Pinocchio and the Emperor of the Night
# 6                          The Possession
# 7                            Control Room
# 8                  Muppet Treasure Island
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 5                                                NaN
# 6                                                NaN
# 7  [{'id': 917, 'name': 'journalism'}, {'id': 163...
# 8  [{'id': 2041, 'name': 'island'}, {'id': 4418, ...
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 5  [{'cast_id': 6, 'character': 'Pinocchio (voice...
# 6  [{'cast_id': 23, 'character': 'Clyde', 'credit...
# 7  [{'cast_id': 2, 'character': 'Himself', 'credi...
# 8  [{'cast_id': 1, 'character': 'Long John Silver...
#
#                                                 crew   revenue
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651
# 5  [{'credit_id': '52fe46f49251416c9106558b', 'de...   3261638
# 6  [{'credit_id': '52fe4981c3a368484e12ee29', 'de...  85446075
# 7  [{'credit_id': '52fe47a69251416c750a0daf', 'de...   2586511
# 8  [{'credit_id': '52fe43c89251416c7501deb3', 'de...  34327391
#
# [5 rows x 22 columns]

# %%
# Concat both axis
imdb_non_null_runtime = pd.concat([imdb1,imdb2,imdb3])

# %%
imdb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  604 non-null    object
#  1   budget                 3000 non-null   int64
#  2   genres                 2993 non-null   object
#  3   homepage               946 non-null    object
#  4   imdb_id                3000 non-null   object
#  5   original_language      3000 non-null   object
#  6   original_title         3000 non-null   object
#  7   overview               2992 non-null   object
#  8   popularity             3000 non-null   float64
#  9   poster_path            2999 non-null   object
#  10  production_companies   2844 non-null   object
#  11  production_countries   2945 non-null   object
#  12  release_date           3000 non-null   object
#  13  runtime                2998 non-null   float64
#  14  spoken_languages       2980 non-null   object
#  15  status                 3000 non-null   object
#  16  tagline                2403 non-null   object
#  17  title                  3000 non-null   object
#  18  Keywords               2724 non-null   object
#  19  cast                   2987 non-null   object
#  20  crew                   2984 non-null   object
#  21  revenue                3000 non-null   int64
# dtypes: float64(2), int64(2), object(18)
# memory usage: 515.8+ KB

# %%
imdb_df.shape
# Out:
# (3000, 22)

# %%
imdb1.shape,imdb2.shape,imdb3.shape
# Out:
# ((135, 22), (1586, 22), (1277, 22))

# %%
# Concatenate along a particular axis
sample_df = pd.concat([imdb1, imdb2],axis=1)

# %%
sample_df.tail()
# Out:
#      belongs_to_collection  budget genres homepage imdb_id original_language  \
# 2994                   NaN     NaN    NaN      NaN     NaN               NaN
# 2995                   NaN     NaN    NaN      NaN     NaN               NaN
# 2996                   NaN     NaN    NaN      NaN     NaN               NaN
# 2997                   NaN     NaN    NaN      NaN     NaN               NaN
# 2999                   NaN     NaN    NaN      NaN     NaN               NaN
#
#      original_title overview  popularity poster_path  ... release_date  \
# 2994            NaN      NaN         NaN         NaN  ...      9/18/92
# 2995            NaN      NaN         NaN         NaN  ...      4/22/94
# 2996            NaN      NaN         NaN         NaN  ...      3/28/13
# 2997            NaN      NaN         NaN         NaN  ...     10/11/96
# 2999            NaN      NaN         NaN         NaN  ...      9/22/11
#
#      runtime                          spoken_languages    status  \
# 2994   106.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2995   102.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2996   102.0  [{'iso_639_1': 'sv', 'name': 'svenska'}]  Released
# 2997   120.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2999   106.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                 tagline  \
# 2994  Just because you’re accepted doesn’t mean you ...
# 2995  It was supposed to be a routine prisoner trans...
# 2996                                                NaN
# 2997               What's forgotten is not always gone.
# 2999          They stole his life. He's taking it back.
#
#                         title  \
# 2994              School Ties
# 2995                  Chasers
# 2996         We Are the Best!
# 2997  The Long Kiss Goodnight
# 2999                Abduction
#
#                                                Keywords  \
# 2994  [{'id': 6075, 'name': 'sport'}, {'id': 10144, ...
# 2995  [{'id': 378, 'name': 'prison'}, {'id': 572, 'n...
# 2996  [{'id': 1192, 'name': 'sweden'}, {'id': 4470, ...
# 2997  [{'id': 441, 'name': 'assassination'}, {'id': ...
# 2999  [{'id': 591, 'name': 'cia'}, {'id': 822, 'name...
#
#                                                    cast  \
# 2994  [{'cast_id': 2, 'character': 'David Greene', '...
# 2995  [{'cast_id': 2, 'character': 'Rock Reilly', 'c...
# 2996  [{'cast_id': 5, 'character': 'Bobo', 'credit_i...
# 2997  [{'cast_id': 10, 'character': 'Samantha Caine ...
# 2999  [{'cast_id': 2, 'character': 'Nathan Harper', ...
#
#                                                    crew     revenue
# 2994  [{'credit_id': '5637777ac3a3681b4d01f9f5', 'de...  14715067.0
# 2995  [{'credit_id': '52fe4494c3a368484e02ac7d', 'de...   1596687.0
# 2996  [{'credit_id': '5716b72ac3a3686678012c84', 'de...    180590.0
# 2997  [{'credit_id': '52fe443a9251416c7502d579', 'de...  89456761.0
# 2999  [{'credit_id': '5391990d0e0a260fb5001629', 'de...  82087155.0
#
# [5 rows x 44 columns]

# %%
sample_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1721 entries, 1 to 2999
# Data columns (total 44 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  21 non-null     object
#  1   budget                 135 non-null    float64
#  2   genres                 134 non-null    object
#  3   homepage               40 non-null     object
#  4   imdb_id                135 non-null    object
#  5   original_language      135 non-null    object
#  6   original_title         135 non-null    object
#  7   overview               135 non-null    object
#  8   popularity             135 non-null    float64
#  9   poster_path            135 non-null    object
#  10  production_companies   125 non-null    object
#  11  production_countries   134 non-null    object
#  12  release_date           135 non-null    object
#  13  runtime                135 non-null    float64
#  14  spoken_languages       135 non-null    object
#  15  status                 135 non-null    object
#  16  tagline                85 non-null     object
#  17  title                  135 non-null    object
#  18  Keywords               120 non-null    object
#  19  cast                   132 non-null    object
#  20  crew                   132 non-null    object
#  21  revenue                135 non-null    float64
#  22  belongs_to_collection  297 non-null    object
#  23  budget                 1586 non-null   float64
#  24  genres                 1584 non-null   object
#  25  homepage               529 non-null    object
#  26  imdb_id                1586 non-null   object
#  27  original_language      1586 non-null   object
#  28  original_title         1586 non-null   object
#  29  overview               1586 non-null   object
#  30  popularity             1586 non-null   float64
#  31  poster_path            1586 non-null   object
#  32  production_companies   1535 non-null   object
#  33  production_countries   1568 non-null   object
#  34  release_date           1586 non-null   object
#  35  runtime                1586 non-null   float64
#  36  spoken_languages       1580 non-null   object
#  37  status                 1586 non-null   object
#  38  tagline                1312 non-null   object
#  39  title                  1586 non-null   object
#  40  Keywords               1476 non-null   object
#  41  cast                   1577 non-null   object
#  42  crew                   1576 non-null   object
#  43  revenue                1586 non-null   float64
# dtypes: float64(8), object(36)
# memory usage: 605.0+ KB

# %%
imdb1.shape, imdb2.shape
# Out:
# ((135, 22), (1586, 22))

# %%
sample_df.columns
# Out:
# Index(['belongs_to_collection', 'budget', 'genres', 'homepage', 'imdb_id',
#        'original_language', 'original_title', 'overview', 'popularity',
#        'poster_path', 'production_companies', 'production_countries',
#        'release_date', 'runtime', 'spoken_languages', 'status', 'tagline',
#        'title', 'Keywords', 'cast', 'crew', 'revenue', 'belongs_to_collection',
#        'budget', 'genres', 'homepage', 'imdb_id', 'original_language',
#        'original_title', 'overview', 'popularity', 'poster_path',
#        'production_companies', 'production_countries', 'release_date',
#        'runtime', 'spoken_languages', 'status', 'tagline', 'title', 'Keywords',
#        'cast', 'crew', 'revenue'],
#       dtype='object')

# %% [markdown]
# # Now let's do some joins
#
# * Inner join
# * Left join
# * Right join
# * Outer join

# %% [markdown]
# ![join-types-merge-names.jpg](data:image/jpeg;base64,...)

# %%
# Let us create a dataframe which consists of only English movies
english_movies = imdb_df[imdb_df['original_language'] == 'en']

# Next let us create another dataframe which consists of only those movies whose length is greater than 100 mins
long_movies = imdb_df.loc[imdb_df['runtime'] >= 100,['imdb_id','original_language']]

# %%
english_movies.shape, long_movies.shape
# Out:
# ((2575, 22), (1820, 2))

# %%
type(long_movies)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # <u><b> Using inner join to merge the two dataframes

# %%
# Merging the two dataframes using inner join
merged_IJ_df = pd.merge(english_movies, long_movies, how='inner',left_on='imdb_id',right_on='imdb_id')

# %%
merged_IJ_df
# Out:
#                                   belongs_to_collection    budget  \
# 0     [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 1                                                   NaN   3300000
# 2     [{'id': 256377, 'name': 'The Muppet Collection...         0
# 3     [{'id': 1575, 'name': 'Rocky Collection', 'pos...   1000000
# 4                                                   NaN  15000000
# ...                                                 ...       ...
# 1523                                                NaN  60000000
# 1524                                                NaN         0
# 1525                                                NaN         0
# 1526                                                NaN  65000000
# 1527                                                NaN  35000000
#
#                                                  genres  \
# 0     [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 1                         [{'id': 18, 'name': 'Drama'}]
# 2     [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 3                         [{'id': 18, 'name': 'Drama'}]
# 4                         [{'id': 18, 'name': 'Drama'}]
# ...                                                 ...
# 1523  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 1524                      [{'id': 18, 'name': 'Drama'}]
# 1525  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 1526  [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...
# 1527  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
#
#                                   homepage    imdb_id original_language_x  \
# 0                                      NaN  tt0368933                  en
# 1        http://sonyclassics.com/whiplash/  tt2582802                  en
# 2                                      NaN  tt0117110                  en
# 3                                      NaN  tt0075148                  en
# 4            http://www.dreamworks.com/ab/  tt0169547                  en
# ...                                    ...        ...                 ...
# 1523  http://www.theterminal-themovie.com/  tt0362227                  en
# 1524                                   NaN  tt0105327                  en
# 1525                                   NaN  tt0109403                  en
# 1526                                   NaN  tt0116908                  en
# 1527      http://www.abductionthefilm.com/  tt1600195                  en
#
#                                 original_title  \
# 0     The Princess Diaries 2: Royal Engagement
# 1                                     Whiplash
# 2                       Muppet Treasure Island
# 3                                        Rocky
# 4                              American Beauty
# ...                                        ...
# 1523                              The Terminal
# 1524                               School Ties
# 1525                                   Chasers
# 1526                   The Long Kiss Goodnight
# 1527                                 Abduction
#
#                                                overview  popularity  \
# 0     Mia Thermopolis is now a college graduate and ...    8.248895
# 1     Under the direction of a ruthless instructor, ...   64.299990
# 2     After telling the story of Flint's last journe...    6.902423
# 3     When world heavyweight boxing champion, Apollo...   14.774066
# 4     Lester Burnham, a depressed suburban father in...   20.726578
# ...                                                 ...         ...
# 1523  Viktor Navorski is a man without a country; hi...   14.092373
# 1524  When David Greene receives a football scholars...    7.438381
# 1525  Military men Rock Reilly and Eddie Devane are ...    9.853270
# 1526  Samantha Caine, suburban homemaker, is the ide...   14.482345
# 1527  A young man sets out to uncover the truth abou...   10.512109
#
#                            poster_path  ... runtime  \
# 0     /w9Z7A0GHEhIp7etpj0vyKOeU1Wx.jpg  ...   113.0
# 1     /lIv1QinFqz4dlp5U4lQ6HaiskOZ.jpg  ...   105.0
# 2     /5A8gKzOrF9Z7tSUX6xd5dEx4NXf.jpg  ...   100.0
# 3     /i5xiwdSsrecBvO7mIfAJixeEDSg.jpg  ...   119.0
# 4     /or1MP8BZIAjqWYxPdPX724ydKar.jpg  ...   122.0
# ...                                ...  ...     ...
# 1523  /f4Dup6awDfDqAHKgWqNJ2HFw1qN.jpg  ...   128.0
# 1524  /poV3j71mcmQkmjezc2H35xJsAhD.jpg  ...   106.0
# 1525  /j8Q7pQ27hvH54wpxJzIuQgQCdro.jpg  ...   102.0
# 1526  /4MENR8x6mYqnZvp2hGjSaPJz64J.jpg  ...   120.0
# 1527  /cUT6NQP5LAJpmUoStGtXmvNt4zA.jpg  ...   106.0
#
#                                        spoken_languages    status  \
# 0              [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1              [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2              [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3              [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4              [{'iso_639_1': 'en', 'name': 'English'}]  Released
# ...                                                 ...       ...
# 1523  [{'iso_639_1': 'bg', 'name': 'български език'}...  Released
# 1524           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1525           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1526           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1527           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                 tagline  \
# 0     It can take a lifetime to find true love; she'...
# 1       The road to greatness can take you to the edge.
# 2                           Set sail for Muppet mayhem!
# 3             His whole life was a million-to-one shot.
# 4                                          Look closer.
# ...                                                 ...
# 1523                                   Life is waiting.
# 1524  Just because you’re accepted doesn’t mean you ...
# 1525  It was supposed to be a routine prisoner trans...
# 1526               What's forgotten is not always gone.
# 1527          They stole his life. He's taking it back.
#
#                                          title  \
# 0     The Princess Diaries 2: Royal Engagement
# 1                                     Whiplash
# 2                       Muppet Treasure Island
# 3                                        Rocky
# 4                              American Beauty
# ...                                        ...
# 1523                              The Terminal
# 1524                               School Ties
# 1525                                   Chasers
# 1526                   The Long Kiss Goodnight
# 1527                                 Abduction
#
#                                                Keywords  \
# 0     [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 1     [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 2     [{'id': 2041, 'name': 'island'}, {'id': 4418, ...
# 3     [{'id': 240, 'name': 'underdog'}, {'id': 276, ...
# 4     [{'id': 255, 'name': 'male nudity'}, {'id': 29...
# ...                                                 ...
# 1523  [{'id': 242, 'name': 'new york'}, {'id': 822, ...
# 1524  [{'id': 6075, 'name': 'sport'}, {'id': 10144, ...
# 1525  [{'id': 378, 'name': 'prison'}, {'id': 572, 'n...
# 1526  [{'id': 441, 'name': 'assassination'}, {'id': ...
# 1527  [{'id': 591, 'name': 'cia'}, {'id': 822, 'name...
#
#                                                    cast  \
# 0     [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 1     [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 2     [{'cast_id': 1, 'character': 'Long John Silver...
# 3     [{'cast_id': 16, 'character': 'Rocky Balboa', ...
# 4     [{'cast_id': 6, 'character': 'Lester Burnham',...
# ...                                                 ...
# 1523  [{'cast_id': 4, 'character': 'Viktor Navorski'...
# 1524  [{'cast_id': 2, 'character': 'David Greene', '...
# 1525  [{'cast_id': 2, 'character': 'Rock Reilly', 'c...
# 1526  [{'cast_id': 10, 'character': 'Samantha Caine ...
# 1527  [{'cast_id': 2, 'character': 'Nathan Harper', ...
#
#                                                    crew    revenue  \
# 0     [{'credit_id': '52fe43fe9251416c7502563d', 'de...   95149435
# 1     [{'credit_id': '54d5356ec3a3683ba0000039', 'de...   13092000
# 2     [{'credit_id': '52fe43c89251416c7501deb3', 'de...   34327391
# 3     [{'credit_id': '579948e9c3a36874e9007b0b', 'de...  117235147
# 4     [{'credit_id': '52fe420ec3a36847f80007c5', 'de...  356296601
# ...                                                 ...        ...
# 1523  [{'credit_id': '52fe4259c3a36847f8017699', 'de...  219417255
# 1524  [{'credit_id': '5637777ac3a3681b4d01f9f5', 'de...   14715067
# 1525  [{'credit_id': '52fe4494c3a368484e02ac7d', 'de...    1596687
# 1526  [{'credit_id': '52fe443a9251416c7502d579', 'de...   89456761
# 1527  [{'credit_id': '5391990d0e0a260fb5001629', 'de...   82087155
#
#      original_language_y
# 0                     en
# 1                     en
# 2                     en
# 3                     en
# 4                     en
# ...                  ...
# 1523                  en
# 1524                  en
# 1525                  en
# 1526                  en
# 1527                  en
#
# [1528 rows x 23 columns]

# %%
temp_df = imdb_df[(imdb_df['original_language'] == 'en') & (imdb_df['runtime'] >=100)]

# %%
temp_df.shape
# Out:
# (1528, 22)

# %% [markdown]
# # <u><b> Using left join to merge the two dataframes

# %%
# Merging the two dataframes using left join
merged_LJ_df = pd.merge(english_movies, long_movies, how='left',left_on='imdb_id',right_on='imdb_id')

# %%
merged_LJ_df
# Out:
#                                   belongs_to_collection    budget  \
# 0     [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1     [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2                                                   NaN   3300000
# 3                                                   NaN   8000000
# 4                                                   NaN  14000000
# ...                                                 ...       ...
# 2570                                                NaN         0
# 2571                                                NaN         0
# 2572                                                NaN  65000000
# 2573                                                NaN  42000000
# 2574                                                NaN  35000000
#
#                                                  genres  \
# 0                        [{'id': 35, 'name': 'Comedy'}]
# 1     [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                         [{'id': 18, 'name': 'Drama'}]
# 3     [{'id': 16, 'name': 'Animation'}, {'id': 12, '...
# 4     [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
# ...                                                 ...
# 2570                      [{'id': 18, 'name': 'Drama'}]
# 2571  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2572  [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...
# 2573  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2574  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
#
#                                 homepage    imdb_id original_language_x  \
# 0                                    NaN  tt2637294                  en
# 1                                    NaN  tt0368933                  en
# 2      http://sonyclassics.com/whiplash/  tt2582802                  en
# 3                                    NaN  tt0093743                  en
# 4     http://www.thepossessionmovie.com/  tt0431021                  en
# ...                                  ...        ...                 ...
# 2570                                 NaN  tt0105327                  en
# 2571                                 NaN  tt0109403                  en
# 2572                                 NaN  tt0116908                  en
# 2573      http://www.alongcamepolly.com/  tt0343135                  en
# 2574    http://www.abductionthefilm.com/  tt1600195                  en
#
#                                 original_title  \
# 0                       Hot Tub Time Machine 2
# 1     The Princess Diaries 2: Royal Engagement
# 2                                     Whiplash
# 3       Pinocchio and the Emperor of the Night
# 4                               The Possession
# ...                                        ...
# 2570                               School Ties
# 2571                                   Chasers
# 2572                   The Long Kiss Goodnight
# 2573                          Along Came Polly
# 2574                                 Abduction
#
#                                                overview  popularity  \
# 0     When Lou, who has become the "father of the In...    6.575393
# 1     Mia Thermopolis is now a college graduate and ...    8.248895
# 2     Under the direction of a ruthless instructor, ...   64.299990
# 3     Pinocchio and his friends, a glow worm and a m...    0.743274
# 4     A young girl buys an antique box at a yard sal...    7.286477
# ...                                                 ...         ...
# 2570  When David Greene receives a football scholars...    7.438381
# 2571  Military men Rock Reilly and Eddie Devane are ...    9.853270
# 2572  Samantha Caine, suburban homemaker, is the ide...   14.482345
# 2573  Reuben Feffer is a guy who's spent his entire ...   15.725542
# 2574  A young man sets out to uncover the truth abou...   10.512109
#
#                            poster_path  ... runtime  \
# 0     /tQtWuwvMf0hCc2QR2tkolwl7c3c.jpg  ...    93.0
# 1     /w9Z7A0GHEhIp7etpj0vyKOeU1Wx.jpg  ...   113.0
# 2     /lIv1QinFqz4dlp5U4lQ6HaiskOZ.jpg  ...   105.0
# 3     /6IDqA1D2NBIVhzEEaMMRL28iBrq.jpg  ...    83.0
# 4     /4QjzFuaZmB4btGnLwAgdp23BzIU.jpg  ...    92.0
# ...                                ...  ...     ...
# 2570  /poV3j71mcmQkmjezc2H35xJsAhD.jpg  ...   106.0
# 2571  /j8Q7pQ27hvH54wpxJzIuQgQCdro.jpg  ...   102.0
# 2572  /4MENR8x6mYqnZvp2hGjSaPJz64J.jpg  ...   120.0
# 2573  /nIY4kvJTTnxoBR0wycrXng5MOYs.jpg  ...    90.0
# 2574  /cUT6NQP5LAJpmUoStGtXmvNt4zA.jpg  ...   106.0
#
#                               spoken_languages    status  \
# 0     [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1     [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2     [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3     [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4     [{'iso_639_1': 'en', 'name': 'English'}]  Released
# ...                                        ...       ...
# 2570  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2571  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2572  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2573  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2574  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                 tagline  \
# 0     The Laws of Space and Time are About to be Vio...
# 1     It can take a lifetime to find true love; she'...
# 2       The road to greatness can take you to the edge.
# 3                                                   NaN
# 4                  Fear The Demon That Doesn't Fear God
# ...                                                 ...
# 2570  Just because you’re accepted doesn’t mean you ...
# 2571  It was supposed to be a routine prisoner trans...
# 2572               What's forgotten is not always gone.
# 2573  For the most cautious man on Earth, life is ab...
# 2574          They stole his life. He's taking it back.
#
#                                          title  \
# 0                       Hot Tub Time Machine 2
# 1     The Princess Diaries 2: Royal Engagement
# 2                                     Whiplash
# 3       Pinocchio and the Emperor of the Night
# 4                               The Possession
# ...                                        ...
# 2570                               School Ties
# 2571                                   Chasers
# 2572                   The Long Kiss Goodnight
# 2573                          Along Came Polly
# 2574                                 Abduction
#
#                                                Keywords  \
# 0     [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1     [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2     [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2570  [{'id': 6075, 'name': 'sport'}, {'id': 10144, ...
# 2571  [{'id': 378, 'name': 'prison'}, {'id': 572, 'n...
# 2572  [{'id': 441, 'name': 'assassination'}, {'id': ...
# 2573  [{'id': 966, 'name': 'beach'}, {'id': 2676, 'n...
# 2574  [{'id': 591, 'name': 'cia'}, {'id': 822, 'name...
#
#                                                    cast  \
# 0     [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1     [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2     [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3     [{'cast_id': 6, 'character': 'Pinocchio (voice...
# 4     [{'cast_id': 23, 'character': 'Clyde', 'credit...
# ...                                                 ...
# 2570  [{'cast_id': 2, 'character': 'David Greene', '...
# 2571  [{'cast_id': 2, 'character': 'Rock Reilly', 'c...
# 2572  [{'cast_id': 10, 'character': 'Samantha Caine ...
# 2573  [{'cast_id': 8, 'character': 'Reuben Feffer', ...
# 2574  [{'cast_id': 2, 'character': 'Nathan Harper', ...
#
#                                                    crew    revenue  \
# 0     [{'credit_id': '59ac067c92514107af02c8c8', 'de...   12314651
# 1     [{'credit_id': '52fe43fe9251416c7502563d', 'de...   95149435
# 2     [{'credit_id': '54d5356ec3a3683ba0000039', 'de...   13092000
# 3     [{'credit_id': '52fe46f49251416c9106558b', 'de...    3261638
# 4     [{'credit_id': '52fe4981c3a368484e12ee29', 'de...   85446075
# ...                                                 ...        ...
# 2570  [{'credit_id': '5637777ac3a3681b4d01f9f5', 'de...   14715067
# 2571  [{'credit_id': '52fe4494c3a368484e02ac7d', 'de...    1596687
# 2572  [{'credit_id': '52fe443a9251416c7502d579', 'de...   89456761
# 2573  [{'credit_id': '556f817b9251410866000a63', 'de...  171963386
# 2574  [{'credit_id': '5391990d0e0a260fb5001629', 'de...   82087155
#
#      original_language_y
# 0                    NaN
# 1                     en
# 2                     en
# 3                    NaN
# 4                    NaN
# ...                  ...
# 2570                  en
# 2571                  en
# 2572                  en
# 2573                 NaN
# 2574                  en
#
# [2575 rows x 23 columns]

# %% [markdown]
# # <u><b> Using right join to merge the two dataframes

# %%
# Merging the two dataframes using right join
merged_RJ_df = pd.merge(english_movies, long_movies, how='right',left_on=['imdb_id'],right_on='imdb_id')

# %%
merged_RJ_df
# Out:
#                                   belongs_to_collection      budget  \
# 0     [{'id': 107674, 'name': 'The Princess Diaries ...  40000000.0
# 1                                                   NaN   3300000.0
# 2                                                   NaN         NaN
# 3                                                   NaN         NaN
# 4     [{'id': 256377, 'name': 'The Muppet Collection...         0.0
# ...                                                 ...         ...
# 1815                                                NaN         0.0
# 1816                                                NaN         0.0
# 1817                                                NaN         NaN
# 1818                                                NaN  65000000.0
# 1819                                                NaN  35000000.0
#
#                                                  genres  \
# 0     [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 1                         [{'id': 18, 'name': 'Drama'}]
# 2                                                   NaN
# 3                                                   NaN
# 4     [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# ...                                                 ...
# 1815                      [{'id': 18, 'name': 'Drama'}]
# 1816  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 1817                                                NaN
# 1818  [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...
# 1819  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
#
#                                homepage    imdb_id original_language_x  \
# 0                                   NaN  tt0368933                  en
# 1     http://sonyclassics.com/whiplash/  tt2582802                  en
# 2                                   NaN  tt1821480                 NaN
# 3                                   NaN  tt1380152                 NaN
# 4                                   NaN  tt0117110                  en
# ...                                 ...        ...                 ...
# 1815                                NaN  tt0105327                  en
# 1816                                NaN  tt0109403                  en
# 1817                                NaN  tt2364975                 NaN
# 1818                                NaN  tt0116908                  en
# 1819   http://www.abductionthefilm.com/  tt1600195                  en
#
#                                 original_title  \
# 0     The Princess Diaries 2: Royal Engagement
# 1                                     Whiplash
# 2                                          NaN
# 3                                          NaN
# 4                       Muppet Treasure Island
# ...                                        ...
# 1815                               School Ties
# 1816                                   Chasers
# 1817                                       NaN
# 1818                   The Long Kiss Goodnight
# 1819                                 Abduction
#
#                                                overview  popularity  \
# 0     Mia Thermopolis is now a college graduate and ...    8.248895
# 1     Under the direction of a ruthless instructor, ...   64.299990
# 2                                                   NaN         NaN
# 3                                                   NaN         NaN
# 4     After telling the story of Flint's last journe...    6.902423
# ...                                                 ...         ...
# 1815  When David Greene receives a football scholars...    7.438381
# 1816  Military men Rock Reilly and Eddie Devane are ...    9.853270
# 1817                                                NaN         NaN
# 1818  Samantha Caine, suburban homemaker, is the ide...   14.482345
# 1819  A young man sets out to uncover the truth abou...   10.512109
#
#                            poster_path  ... runtime  \
# 0     /w9Z7A0GHEhIp7etpj0vyKOeU1Wx.jpg  ...   113.0
# 1     /lIv1QinFqz4dlp5U4lQ6HaiskOZ.jpg  ...   105.0
# 2                                  NaN  ...     NaN
# 3                                  NaN  ...     NaN
# 4     /5A8gKzOrF9Z7tSUX6xd5dEx4NXf.jpg  ...   100.0
# ...                                ...  ...     ...
# 1815  /poV3j71mcmQkmjezc2H35xJsAhD.jpg  ...   106.0
# 1816  /j8Q7pQ27hvH54wpxJzIuQgQCdro.jpg  ...   102.0
# 1817                               NaN  ...     NaN
# 1818  /4MENR8x6mYqnZvp2hGjSaPJz64J.jpg  ...   120.0
# 1819  /cUT6NQP5LAJpmUoStGtXmvNt4zA.jpg  ...   106.0
#
#                               spoken_languages    status  \
# 0     [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1     [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2                                          NaN       NaN
# 3                                          NaN       NaN
# 4     [{'iso_639_1': 'en', 'name': 'English'}]  Released
# ...                                        ...       ...
# 1815  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1816  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1817                                       NaN       NaN
# 1818  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1819  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                 tagline  \
# 0     It can take a lifetime to find true love; she'...
# 1       The road to greatness can take you to the edge.
# 2                                                   NaN
# 3                                                   NaN
# 4                           Set sail for Muppet mayhem!
# ...                                                 ...
# 1815  Just because you’re accepted doesn’t mean you ...
# 1816  It was supposed to be a routine prisoner trans...
# 1817                                                NaN
# 1818               What's forgotten is not always gone.
# 1819          They stole his life. He's taking it back.
#
#                                          title  \
# 0     The Princess Diaries 2: Royal Engagement
# 1                                     Whiplash
# 2                                          NaN
# 3                                          NaN
# 4                       Muppet Treasure Island
# ...                                        ...
# 1815                               School Ties
# 1816                                   Chasers
# 1817                                       NaN
# 1818                   The Long Kiss Goodnight
# 1819                                 Abduction
#
#                                                Keywords  \
# 0     [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 1     [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 2                                                   NaN
# 3                                                   NaN
# 4     [{'id': 2041, 'name': 'island'}, {'id': 4418, ...
# ...                                                 ...
# 1815  [{'id': 6075, 'name': 'sport'}, {'id': 10144, ...
# 1816  [{'id': 378, 'name': 'prison'}, {'id': 572, 'n...
# 1817                                                NaN
# 1818  [{'id': 441, 'name': 'assassination'}, {'id': ...
# 1819  [{'id': 591, 'name': 'cia'}, {'id': 822, 'name...
#
#                                                    cast  \
# 0     [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 1     [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 2                                                   NaN
# 3                                                   NaN
# 4     [{'cast_id': 1, 'character': 'Long John Silver...
# ...                                                 ...
# 1815  [{'cast_id': 2, 'character': 'David Greene', '...
# 1816  [{'cast_id': 2, 'character': 'Rock Reilly', 'c...
# 1817                                                NaN
# 1818  [{'cast_id': 10, 'character': 'Samantha Caine ...
# 1819  [{'cast_id': 2, 'character': 'Nathan Harper', ...
#
#                                                    crew     revenue  \
# 0     [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435.0
# 1     [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000.0
# 2                                                   NaN         NaN
# 3                                                   NaN         NaN
# 4     [{'credit_id': '52fe43c89251416c7501deb3', 'de...  34327391.0
# ...                                                 ...         ...
# 1815  [{'credit_id': '5637777ac3a3681b4d01f9f5', 'de...  14715067.0
# 1816  [{'credit_id': '52fe4494c3a368484e02ac7d', 'de...   1596687.0
# 1817                                                NaN         NaN
# 1818  [{'credit_id': '52fe443a9251416c7502d579', 'de...  89456761.0
# 1819  [{'credit_id': '5391990d0e0a260fb5001629', 'de...  82087155.0
#
#      original_language_y
# 0                     en
# 1                     en
# 2                     hi
# 3                     ko
# 4                     en
# ...                  ...
# 1815                  en
# 1816                  en
# 1817                  sv
# 1818                  en
# 1819                  en
#
# [1820 rows x 23 columns]

# %% [markdown]
# # <u><b> Using outer join to merge the two dataframes

# %%
# Outer Join
merged_OJ_df = pd.merge(english_movies[['imdb_id','runtime']],long_movies, on='imdb_id', how='outer')

# %%
merged_OJ_df
# Out:
#         imdb_id  runtime original_language
# 0     tt2637294     93.0               NaN
# 1     tt0368933    113.0                en
# 2     tt2582802    105.0                en
# 3     tt0093743     83.0               NaN
# 4     tt0431021     92.0               NaN
# ...         ...      ...               ...
# 2862  tt2106741      NaN                zh
# 2863  tt1093370      NaN                hi
# 2864  tt1194664      NaN                ja
# 2865  tt5320514      NaN                ml
# 2866  tt2364975      NaN                sv
#
# [2867 rows x 3 columns]

# %% [markdown]
# ## *Finally let us do some <code>groupby</code> operations**

# %%
# Importing datetime modules
from datetime import datetime
from datetime import date

# %%
def parse_string_to_date(datestring):

  return convert_to_year(datestring)

# %%
imdb_df['new_release_date_2']= imdb_df.apply(lambda x : datetime.strptime(x['release_date'],'%m/%d/%y'),axis=1)

# %%
def convert_to_year(datevalue):
  return datevalue.year

# %%
imdb_df['Year_of_release_1'] = imdb_df['new_release_date_2'].apply(convert_to_year)

# %%
imdb_df['new_release_date_2'][2].year
# Out:
# 2014

# %%
imdb_df.head()
# Out:
#                                belongs_to_collection    budget  \
# 0  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2                                                NaN   3300000
# 3                                                NaN   1200000
# 4                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# 2  http://sonyclassics.com/whiplash/  tt2582802                en
# 3         http://kahaanithefilm.com/  tt1821480                hi
# 4                                NaN  tt1380152                ko
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                      마린보이
#
#                                             overview  popularity  \
# 0  When Lou, who has become the "father of the In...    6.575393
# 1  Mia Thermopolis is now a college graduate and ...    8.248895
# 2  Under the direction of a ruthless instructor, ...   64.299990
# 3  Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936
# 4  Marine Boy is the story of a former national s...    1.148070
#
#                         poster_path  ...  \
# 0  /tQtWuwvMf0hCc2QR2tkolwl7c3c.jpg  ...
# 1  /w9Z7A0GHEhIp7etpj0vyKOeU1Wx.jpg  ...
# 2  /lIv1QinFqz4dlp5U4lQ6HaiskOZ.jpg  ...
# 3  /aTXRaPrWSinhcmCrcfJK17urp3F.jpg  ...
# 4  /m22s7zvkVFDU9ir56PiiqIEWFdT.jpg  ...
#
#                                     spoken_languages    status  \
# 0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 4           [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]  Released
#
#                                              tagline  \
# 0  The Laws of Space and Time are About to be Vio...
# 1  It can take a lifetime to find true love; she'...
# 2    The road to greatness can take you to the edge.
# 3                                                NaN
# 4                                                NaN
#
#                                       title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1  [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2  [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 3  [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 4                                                NaN
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1  [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2  [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3  [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4  [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
#
#                                                 crew   revenue  \
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651
# 1  [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435
# 2  [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000
# 3  [{'credit_id': '52fe48779251416c9108d6eb', 'de...  16000000
# 4  [{'credit_id': '52fe464b9251416c75073b43', 'de...   3923970
#
#   new_release_date_2 Year_of_release_1
# 0         2015-02-20              2015
# 1         2004-08-06              2004
# 2         2014-10-10              2014
# 3         2012-03-09              2012
# 4         2009-02-05              2009
#
# [5 rows x 24 columns]

# %%
imdb_df['Year_of_release_1'] = np.where(imdb_df['Year_of_release_1'] > 2020,imdb_df['Year_of_release_1'] - 100,imdb_df['Year_of_release_1'])

# %%
imdb_df['Year_of_release_1'].min()
# Out:
# 1921

# %%
# We can find the maximum movie runtime across different years
max_runtime_movies_by_year = imdb_df.groupby('Year_of_release_1')['runtime'].max().reset_index()

# %%
max_runtime_movies_by_year.rename(columns = {'runtime' : 'max_runtime'},inplace=True)

# %%
max_runtime_movies_by_year.head()
# Out:
#    Year_of_release_1  max_runtime
# 0               1921         68.0
# 1               1924        149.0
# 2               1925        137.0
# 3               1926         84.0
# 4               1927         94.0

# %%
# We can find the maximum movie runtime across different years
imdb_df.groupby('Year_of_release_1')['runtime'].median().reset_index()
# Out:
#     Year_of_release_1  runtime
# 0                1921     68.0
# 1                1924    149.0
# 2                1925    106.0
# 3                1926     84.0
# 4                1927     87.0
# ..                ...      ...
# 85               2013    105.0
# 86               2014    104.0
# 87               2015    108.5
# 88               2016    107.0
# 89               2017    106.5
#
# [90 rows x 2 columns]

# %%
imdb_df.groupby('Year_of_release_1')['imdb_id'].count().median()
# Out:
# 8.0

# %%
imdb_df.groupby('Year_of_release_1', as_index=False).agg({"runtime": "sum"})
# Out:
#     Year_of_release_1  runtime
# 0                1921     68.0
# 1                1924    149.0
# 2                1925    212.0
# 3                1926     84.0
# 4                1927    174.0
# ..                ...      ...
# 85               2013  15350.0
# 86               2014  12966.0
# 87               2015  14328.0
# 88               2016  13573.0
# 89               2017   4446.0
#
# [90 rows x 2 columns]

# %%
imdb_df.groupby(['Year_of_release_1', 'original_language'],as_index=False)

# %%
# Group the data frame by month and item and extract a number of stats from each group
imdb_df.groupby(['Year_of_release_1', 'original_language'],as_index=False).agg({'runtime':"mean",'revenue': "sum",'imdb_id':"count"}).sort_values(by='Year_of_release_1').rename(columns ={'runtime':'avg_runtime','revenue':'total_revenue','imdb_id':'num_movies'})
# Out:
#      Year_of_release_1 original_language  avg_runtime  total_revenue  \
# 0                 1921                en    68.000000        2500000
# 1                 1924                en   149.000000        1213880
# 2                 1925                en   137.000000              1
# 3                 1925                ru    75.000000          45100
# 4                 1926                en    84.000000         966878
# ..                 ...               ...          ...            ...
# 346               2017                ru   140.000000        9868942
# 343               2017                en   110.542857     7215048462
# 344               2017                es    91.500000        6440000
# 345               2017                fr    86.000000        7800000
# 347               2017                ta   168.000000       17000000
#
#      num_movies
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
# ..          ...
# 346           1
# 343          35
# 344           2
# 345           1
# 347           1
#
# [348 rows x 5 columns]

# %% [markdown]
# ##### Visualization using pandas

# %%
xx=df.head(25)

# %%
xx.plot(x='original_language',y='revenue',title='Line Chart')
# Out:
# <AxesSubplot:title={'center':'Line Chart'}, xlabel='original_language'>

# %%
xx.plot.scatter(x='popularity',y='revenue',title='Scatter plot')
# Out:
# <AxesSubplot:title={'center':'Scatter plot'}, xlabel='popularity', ylabel='revenue'>

# %%
ss=xx['original_language'].unique()

# %%
ss
# Out:
# array(['en', 'hi', 'ko', 'sr'], dtype=object)

# %%
xx.plot.bar(x='title',y='revenue',title='Barplot',figsize=(15,11))
# Out:
# <AxesSubplot:title={'center':'Barplot'}, xlabel='title'>
